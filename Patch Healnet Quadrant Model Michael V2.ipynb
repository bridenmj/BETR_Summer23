# %% [markdown]
# # Patch Healnet Quadrant Model
#
# ### Healing Stages
# * `Hemostasis:`  Initial injury or wound debrided (damaged tissue is removed using surgical instruments) during the past 48 hours. ***Indicator: Wound edges are sharp and obvious. Blood clots may be visible.***
#
# * `Inflammatory:` Begins immediately after injury. Duration varies based on presence of infection. ***Indicator: Redness or swelling of the wound edge. Wet or shiny appearance of wound exudate (fluid that has seeped out of tissue). If infected, pus may be visible.***
#
# * `Proliferative:` Tissue is rebuilt through granulation tissue and re-epithelialization. Wound size is reduced by contraction.. ***Indicator: Loss of shiny appearance as wound dries and exudate becomes granulation tissue. Wound edge and center texture may be uneven or variable. Re-epithelializaton forms new epithelium that may have pink coloring, distinguishing it from surrounding intact skin and granulation tissue in the center of the wound. New blood vessels (angiogenesis) may be visible. Overall reduction in wound size as wound contracts.***
#
# * `Maturation:` Also called the remodeling stage of wound healing, tissue is reorganized and strengthened at a cellular level. ***Indicator: Healed with no open wound visible. Hair growth may be seen as skin appendages reform.***
#
# #### References
# * Shi, et al. (2015). Convolutional LSTM Network: A Machine Learning Approach for Precipitation Nowcasting. Retrieved December 11th, 2020, from the arXiv database
# * S.M. Ali Eslami, et al. (2016). Attend, Infer, Repeat: Fast Scene Understanding with Generative Models. Retrieved Oct 20th, 2020, from the arXiv database
# * Karol Gregor, et al. (2016). Towards Conceptual Compression. Retrieved Oct 20th, 2020, from the arXiv database
# * S.M. Ali Eslami, et al. (2020). Representation Learning Without Labels ICML 2020
# * H. Carrión et al. (2020). Automatic Wound Detection and Size Estimation using Deep Learning Algorithms. Retrieved November 2020 from the biorXiv databse
# * Maity et al. Advanced Computational and Communication Paradigms. 2020
# * Hinton et al. Science. 2006; 313
# * Chino et al. Computer Methods and Programs in Biomedicine. 2020

# %%
# Run this cell to revert to tf 2.10.0
# Restart runtime once the installs have finished

# !pip uninstall tensorflow -y

print(f"\n installing tensorflow 2.10.0")
# !pip install tensorflow==2.10.0

print(f"uninstalling keras-cv")
# !pip uninstall keras-cv -y
print(f"installing keras-cv 0.2.10")
# !pip install keras-cv==0.2.10
# Out:
# Found existing installation: tensorflow 2.14.0
# Uninstalling tensorflow-2.14.0:
#   Successfully uninstalled tensorflow-2.14.0
#
#  installing tensorflow 2.10.0
# Collecting tensorflow==2.10.0
#   Downloading tensorflow-2.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (578.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 578.0/578.0 MB 1.7 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (23.5.26)
# Collecting gast<=0.4.0,>=0.2.1 (from tensorflow==2.10.0)
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (1.59.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (3.9.0)
# Collecting keras<2.11,>=2.10.0 (from tensorflow==2.10.0)
#   Downloading keras-2.10.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 78.0 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1 (from tensorflow==2.10.0)
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (23.2)
# Collecting protobuf<3.20,>=3.9.2 (from tensorflow==2.10.0)
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 82.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (1.16.0)
# Collecting tensorboard<2.11,>=2.10 (from tensorflow==2.10.0)
#   Downloading tensorboard-2.10.1-py3-none-any.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 87.1 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (0.34.0)
# Collecting tensorflow-estimator<2.11,>=2.10.0 (from tensorflow==2.10.0)
#   Downloading tensorflow_estimator-2.10.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 48.0 MB/s eta 0:00:00
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow==2.10.0) (1.14.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow==2.10.0) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.17.3)
# Collecting google-auth-oauthlib<0.5,>=0.4.1 (from tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.31.0)
# Collecting tensorboard-data-server<0.7.0,>=0.6.0 (from tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 63.7 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0 (from tensorboard<2.11,>=2.10->tensorflow==2.10.0)
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 54.7 MB/s eta 0:00:00
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.2.2)
# Installing collected packages: tensorboard-plugin-wit, keras, tensorflow-estimator, tensorboard-data-server, protobuf, keras-preprocessing, gast, google-auth-oauthlib, tensorboard, tensorflow
#   Attempting uninstall: keras
#     Found existing installation: keras 2.14.0
#     Uninstalling keras-2.14.0:
#       Successfully uninstalled keras-2.14.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.14.0
#     Uninstalling tensorflow-estimator-2.14.0:
#       Successfully uninstalled tensorflow-estimator-2.14.0
#   Attempting uninstall: tensorboard-data-server
#     Found existing installation: tensorboard-data-server 0.7.2
#     Uninstalling tensorboard-data-server-0.7.2:
#       Successfully uninstalled tensorboard-data-server-0.7.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.4
#     Uninstalling gast-0.5.4:
#       Successfully uninstalled gast-0.5.4
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-datasets 4.9.3 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.14.0 requires protobuf<4.21,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# Successfully installed gast-0.4.0 google-auth-oauthlib-0.4.6 keras-2.10.0 keras-preprocessing-1.1.2 protobuf-3.19.6 tensorboard-2.10.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-2.10.0 tensorflow-estimator-2.10.0
# uninstalling keras-cv
# WARNING: Skipping keras-cv as it is not installed.
# installing keras-cv 0.2.10
# Collecting keras-cv==0.2.10
#   Downloading keras_cv-0.2.10-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.4/227.4 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-cv==0.2.10) (23.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras-cv==0.2.10) (1.4.0)
# Installing collected packages: keras-cv
# Successfully installed keras-cv-0.2.10

# %%
import tensorflow as tf
print(f"new tensorflow version {tf.__version__}")
# Out:
# new tensorflow version 2.10.0

# %%
# Load the Drive helper and mount:
from google.colab import drive

# This will prompt for authorization:
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# sets the path to your working directory
# %cd drive/MyDrive/BETR_Summer23
# Out:
# /content/drive/MyDrive/BETR_Summer23

# %%
#!unzip data/exp13_ctl_sep2.zip -d data/exp13_ctl_sep2

# %%
# you'll need to clone this once
# !git clone https://github.com/gabrielibagon/TensorBlur.git

# %%
# !pip install tensorflow_addons

import numpy as np
import math
import tensorflow as tf
import tensorflow_addons as tfa
from keras import backend as K
from tensorflow.keras.optimizers import Adam
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import datasets, layers, models, losses
from keras.layers import TimeDistributed, Conv2D, Conv2DTranspose, ConvLSTM2D, LSTM, Concatenate
from keras.layers import MaxPool2D, Input, Dense, Reshape, Dropout, Activation, Flatten
from keras.models import Sequential
from keras.layers import RandomFlip, RandomRotation, RandomContrast, Layer
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.applications import DenseNet121, DenseNet169, Xception, \
    InceptionV3, NASNetMobile, MobileNetV3Small, ResNet50, MobileNet, VGG16
from keras.layers import Activation, Add, BatchNormalization, Concatenate, \
    Conv2D, Dense, Flatten, GlobalMaxPooling2D, Lambda, MaxPooling2D, Reshape, \
    GlobalAveragePooling2D
from tensorflow.keras.applications.densenet import preprocess_input as densenet_preprocess
from tensorflow.keras.applications.vgg16 import preprocess_input as vgg_preprocess
from tensorflow.keras.applications.resnet import preprocess_input as resnet_preprocess
from tensorflow.keras.applications.inception_v3 import preprocess_input as inception_preprocess
import pandas as pd
from sklearn.cluster import KMeans
from PIL import Image
from matplotlib import pyplot as plt
import glob
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import array_to_img, img_to_array, load_img
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score
from keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau, EarlyStopping
import os
import seaborn as sns
from tqdm.auto import tqdm
from sklearn.model_selection import train_test_split
from matplotlib.transforms import Bbox
from PIL import Image, ImageDraw
from copy import deepcopy
from scipy.ndimage import gaussian_filter
import cv2
from skimage import color as skcolor
from skimage import filters as skfilters
import glob
from copy import deepcopy
print(tf.__version__)
# %matplotlib inline
# %load_ext tensorboard
# Out:
# Collecting tensorflow_addons
#   Downloading tensorflow_addons-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (612 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.3/612.3 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow_addons) (23.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow_addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow_addons
# Successfully installed tensorflow_addons-0.22.0 typeguard-2.13.3
# /usr/local/lib/python3.10/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# 2.14.0

# %% [markdown]
# ## Dataset

# %% [markdown]
# ### Create Device Patch Dataset

# %% [markdown]
# #### Create Train

# %%
#!ls /content/drive/MyDrive/BETR_Summer23/data/train_ctl_sep2_3x4_quad

# %%
from copy import deepcopy
# load patch train images
base_ = '/content/drive/MyDrive/BETR_Summer23/data/Sep2_cleaned_control_images_Patch_Image/train_ctl_sep2_3x4_quad/'
imgs_quad = glob.glob(base_+'*.jpg')

#Create dataframe from images
count = 0
data =  pd.DataFrame(columns=["image","wound","day","quadrant"])
for fn in imgs_quad:
    tmp = fn.split("/")[-1].split("_")
    wound = "".join([tmp[1], tmp[3]]) # Exp-wound combined
    day = tmp[5]
    quad = tmp[7]
    data.loc[len(data.index)] = [fn, wound, day, quad]
    count += 1

print(f"created dataframe of size {data.shape}...")

nump_sample = 10
train_samples = []
train_label = []
count = 0

print("creating training samples...")

#Create training set
for quadrant in ["00", "01","10","11"]:
    for wound in data['wound'].unique():
        #select data from frame by wound and quadrant
        img_sample_df = data[ (data["quadrant"]==quadrant) & (data["wound"]==wound) ].groupby('day').apply(lambda x:  x.sample(nump_sample,replace=False) if len(x) > nump_sample else x.sample(nump_sample,replace=True)).reset_index(drop=True)
        img_arr = np.array(img_sample_df["image"])
        img_arr = img_arr.reshape( len( img_sample_df['day'].unique() ), nump_sample)
        #get days
        x = y = np.arange(0, len( img_sample_df['day'].unique() ), 1)

        # make day combos
        combos = np.array(np.meshgrid(x, y)).T.reshape(-1, 2)
        drops = []
        for i in range(len(combos)):
            if combos[i][0] == combos[i][1]:
                drops.append(i)
            #elif abs(combos[i][0]-combos[i][1]) < 2:
            #    print(combos[i][0], combos[i][1], combos[i][0]-combos[i][1])
            #    drops.append(i)
        combos = np.delete(combos,drops,axis=0)

        #create image combo paths
        for i in range(nump_sample):
            for j in range(i+1, nump_sample):
                for combo in combos:
                    img_1 = (img_arr[combo[0], i])
                    img_2 = (img_arr[combo[1], j])
                    train_samples.append((img_1,img_2))
                    train_label.append(1 if combo[0] > combo[1] else 0)
                    count += 1

#load image combos into numpy arrays
x_train = np.ndarray((count, 2, 128, 128, 3), dtype=np.float32)
y_train = np.array(train_label, dtype=np.int32)
idx = 0

print(f"creating {len(train_samples)} pairs...")
for left_path, right_path in tqdm(train_samples):
    x_train[idx,0,:,:,:] = deepcopy(img_to_array( Image.open(left_path).resize((128,128)) ))
    x_train[idx,1,:,:,:] = deepcopy(img_to_array( Image.open(right_path).resize((128,128)) ))
    idx += 1


print(f" {len(train_samples)} sample pairs created.")
# Out:
# created dataframe of size (39255, 4)...
# creating training samples...
# creating 41760 pairs...
#   0%|          | 0/41760 [00:00<?, ?it/s]
#  41760 sample pairs created.

# %%
# !pwd
# Out:
# /content

# %%
# Save patch images
# with open('data/exp_ctl_sep2_3x4_quad_train.npy', 'wb') as f:
#     np.save(f, train_samples)
#     np.save(f, x_train)
#     np.save(f, y_train)

# %% [markdown]
# #### Create Test set

# %%
base_ = '/content/drive/MyDrive/BETR_Summer23/data/Sep2_cleaned_control_images_Patch_Image/test_ctl_sep2_3x4_quad/'
imgs_quad = glob.glob(base_+'*.jpg')

count = 0

data =  pd.DataFrame(columns=["image","wound","day","quadrant"])
for fn in imgs_quad:
    tmp = fn.split("/")[-1].split("_")
    #print(tmp)
    wound = "".join([tmp[1], tmp[3]]) # Exp-wound combined
    day = tmp[5]
    quad = tmp[7]
    #print(wound)
    data.loc[len(data.index)] = [fn, wound, day, quad]
    count += 1

print(f"created dataframe of size {data.shape}...")

nump_sample = 10
test_samples = []
test_label = []

count = 0

print("creating training samples...")
#Create training set
for quadrant in ["00", "01","10","11"]:
    for wound in data['wound'].unique():
        #select data from frame by wound and quadrant
        img_sample_df = data[ (data["quadrant"]==quadrant) & (data["wound"]==wound) ].groupby('day').apply(lambda x:  x.sample(nump_sample,replace=False) if len(x) > nump_sample else x.sample(nump_sample,replace=True)).reset_index(drop=True)
        img_arr = np.array(img_sample_df["image"])
        img_arr = img_arr.reshape( len( img_sample_df['day'].unique() ), nump_sample)
        #get days
        x = y = np.arange(0, len( img_sample_df['day'].unique() ), 1)

        # make day combos
        combos = np.array(np.meshgrid(x, y)).T.reshape(-1, 2) # make combos
        drops = []
        for i in range(len(combos)):
            if combos[i][0] == combos[i][1]:
                drops.append(i)
        combos = np.delete(combos,drops,axis=0)


        #create image combo paths
        for i in range(nump_sample):
            for j in range(i+1, nump_sample):
                for combo in combos:
                    img_1 = (img_arr[combo[0], i])
                    img_2 = (img_arr[combo[1], j])
                    test_samples.append((img_1,img_2))
                    test_label.append(1 if combo[0] > combo[1] else 0)
                    count += 1

#load image combos into numpy arrays
x_test = np.ndarray((count, 2, 128, 128, 3), dtype=np.float32)
y_test = np.array(test_label, dtype=np.int32)
idx = 0

print(f"creating {len(test_samples)} pairs...")
for left_path, right_path in tqdm(test_samples):
    x_test[idx,0,:,:,:] = deepcopy(img_to_array( Image.open(left_path).resize((128,128)) ))
    x_test[idx,1,:,:,:] = deepcopy(img_to_array( Image.open(right_path).resize((128,128)) ))
    idx += 1


print(f" {len(test_samples)} sample pairs created.")
# Out:
# created dataframe of size (8087, 4)...
# creating training samples...
# creating 13320 pairs...
#   0%|          | 0/13320 [00:00<?, ?it/s]
#  13320 sample pairs created.

# %%
# Save patch images
with open('data/exp_ctl_sep2_3x4_quad_test.npy', 'wb') as f:
    np.save(f, test_samples)
    np.save(f, x_test)
    np.save(f, y_test)

# %% [markdown]
# ### Full Image Temporal Encoder Dataset
# closely resembles technique in the the paper. No Patches.

# %% [markdown]
# #### Train

# %%
# Read in the images
base_train =  'data/Sep2_cleaned_control_images_Full_Image/train_ctl_sep2_3x4_cleaned/'
imgs_train = glob.glob(base_train+'*.jpg')

base_val = 'data/Sep2_cleaned_control_images_Full_Image/test_Exp_ctl_sep2_3x4_cleaned/'
imgs_val = glob.glob(base_val+'*.jpg')

# %%
print( len(imgs_train), len(imgs_val) )
# Out:
# 2459 509

# %%
# Create one big list of images to give them labels
imgs_ = imgs_train + imgs_val
imgs_arr = np.array(imgs_)

# %%
# Save Images
# with open('data/imgs_list.npy', 'wb') as f:
#    np.save(f, imgs_)
#    np.save(f, imgs_)

# %%
# Load images
# with open('data/imgs_combined.npy', 'wb') as f:
#    np.save(f, imgs_)
#    np.save(f, imgs_arr)
# with open('data/imgs_combined.npy', 'rb') as f:
#    imgs_ = np.load(f)
#    imgs_arr = np.load(f)

# %%
# Create dataframe
data =  pd.DataFrame(columns=["image","wound","day"])
for img in imgs_arr:
    tmp = img.split("/")[-1]
    tmp2 = tmp.split("_")
    wound_id = "".join([tmp2[1], tmp2[3]])
    day = int(tmp2[5])
    data.loc[len(data.index)] = [img, wound_id,day]

# %% [markdown]
# # New Section

# %%
nump_sample = 8 # Change this to select the number of patches for each day
train_samples = []
train_label = []
count = 0

L_train_samples = []
R_train_samples = []

# Create image pairs for training images
for wound in [ '127', '123', '107', '103', '113', '117', '87', '83' ]: # REMOVED 13 FOR TEST
    img_sample_df = data[ (data["wound"]==wound) ].groupby('day',group_keys=False).apply(lambda x:  x.sample(nump_sample,replace=False) if len(x) > nump_sample else x.sample(nump_sample,replace=True))
    img_arr = np.array( img_sample_df["image"].index )
    img_arr = img_arr.reshape( len( img_sample_df['day'].unique() ), nump_sample)
    x = y = np.arange(0, len( img_sample_df['day'].unique() ), 1)
    combos = np.array(np.meshgrid(x, y)).T.reshape(-1, 2)
    drops = []
    for i in range(len(combos)):
        if combos[i][0] == combos[i][1]:
            drops.append(i)
    combos = np.delete(combos,drops,axis=0)

    for i in range(nump_sample):
        for j in range(i+1, nump_sample):
            for combo in combos:
                L_train_samples.append(img_arr[combo[0], i])
                R_train_samples.append(img_arr[combo[1], j])

                train_label.append(1 if combo[0] > combo[1] else 0)
                count += 1
#Save to numpy arrays
x_train = deepcopy(np.stack((imgs_arr[L_train_samples],imgs_arr[R_train_samples])))
y_train = np.array(train_label, dtype=np.int32)

print(f"train data shape: {x_train.shape}, label shape: {y_train.shape}")

############################### TEST ###############################

L_test_samples = []
R_test_samples = []
test_samples = []
test_label = []

# Create image pairs for training images
for wound in  ['136', '135', '131', '132']: #  13 FOR TEST
    img_sample_df = data[ (data["wound"]==wound) ].groupby('day',group_keys=False).apply(lambda x:  x.sample(nump_sample,replace=False) if len(x) > nump_sample else x.sample(nump_sample,replace=True))
    img_arr = np.array( img_sample_df["image"].index )
    img_arr = img_arr.reshape( len( img_sample_df['day'].unique() ), nump_sample)
    x = y = np.arange(0, len( img_sample_df['day'].unique() ), 1)
    combos = np.array(np.meshgrid(x, y)).T.reshape(-1, 2)
    drops = []
    for i in range(len(combos)):
        if combos[i][0] == combos[i][1]:
            drops.append(i)
    combos = np.delete(combos,drops,axis=0)

    for i in range(nump_sample):
        for j in range(i+1, nump_sample):
            for combo in combos:
                L_test_samples.append(img_arr[combo[0], i])
                R_test_samples.append(img_arr[combo[1], j])
                test_label.append(1 if combo[0] > combo[1] else 0)
                count += 1
#Save to numpy arrays
x_test = deepcopy(np.stack((imgs_arr[L_test_samples],imgs_arr[R_test_samples]),axis=1))
y_test = np.array(test_label, dtype=np.int32)

print(f"train data shape: {x_test.shape}, label shape: {y_train.shape}")
# Out:
# train data shape: (2, 6496), label shape: (6496,)
# train data shape: (2072, 2), label shape: (6496,)

# %% [markdown]
# #### Load full image train and test data

# %%
# !ls data
# Out:
#  abMIL_12_Train_sep2_cleaned	  'near_quad_tr=0.5'
#  abMIL_12_val_sep2_cleaned	   patch_healnet_arrays
#  exp13_ctl_sep2			  'Pig_Labels_Cleaned_FINALESTFINALLLL (1).gsheet'
#  exp_ctl_sep2_3x4_quad_train.npy   Pig_Labels_Cleaned_FINALESTFINALLLL.csv
#  exp_ctl_sep2_test.npy		   Pig_Labels_Cleaned_FINALESTFINALLLL.gsheet
#  exp_ctl_sep2_train.npy		   Sep2_cleaned_control_images_Full_Image
#  iphone_train			   Sep2_cleaned_control_images_Patch_Image
#  iphone_val			   train_ctl_sep2
#  near				  'Wound Photos by iPhone'

# %%
# Save x-test y-test, x-train,y-train
# Save Images
# with open('data/Positive_Negative_Pair_Dataset_Train.npy', 'wb') as f:
#    np.save(f, x_train)
#    np.save(f, y-train)

# with open('data/Positive_Negative_Pair_Dataset_Test.npy', 'wb') as f:
#    np.save(f, x_test)
#    np.save(f, y-test)

# Patch Load images
with open('data/exp_ctl_sep2_3x4_quad_test.npy', 'rb') as f:
    _ = np.load(f)
    x_test = np.load(f)
    y_test = np.load(f)



print(x_train.shape, x_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (41760, 2, 128, 128, 3) (13320, 2, 128, 128, 3)
# (41760,) (13320,)

# %%
def augment(images):
    images = RandomFlip("horizontal_and_vertical")(images)
    images = RandomRotation(0.5, fill_mode='constant')(images)
    images = RandomContrast(0.5)(images)
    #images = RandomColorDistortion()(images)
    image = GaussianBlur(kernel_size=(3, 3), sigma=(0, 2))(images)
    return images

#print(f" {count} samples created.")

# %% [markdown]
# # Augmentation

# %%
class RandomColorDistortion(tf.keras.layers.Layer):
    def __init__(self, contrast_range=[0.5, 1.5],
                 brightness_delta=[-0.1, 0.1],
                 saturation_range=[0, 0.5],
                 hue_max_delta=0.001,
                 blur=0.5, **kwargs):
        super(RandomColorDistortion, self).__init__(**kwargs)
        self.contrast_range = contrast_range
        self.brightness_delta = brightness_delta
        self.min_sat, self.max_sat = saturation_range
        self.hue_max = hue_max_delta
        self.blur_sigma = blur

    def call(self, images, training=None):
        if not training:
            return images

        contrast = np.random.uniform(
            self.contrast_range[0], self.contrast_range[1])
        brightness = np.random.uniform(
            self.brightness_delta[0], self.brightness_delta[1])

        #images = tf.image.adjust_contrast(images, contrast)
        images = tf.image.adjust_brightness(images, brightness)
        images = tf.image.random_saturation(images, self.min_sat, self.max_sat)
        images = tf.image.random_hue(images, self.hue_max)
        images = tfa.image.gaussian_filter2d(images, self.blur_sigma)

        images = tf.clip_by_value(images, 0, 1)
        return images

# %%
class RandomColorAffine(layers.Layer):
    def __init__(self, brightness=0, jitter=0, **kwargs):
        super().__init__(**kwargs)

        self.brightness = brightness
        self.jitter = jitter

    def get_config(self):
        config = super().get_config()
        config.update({"brightness": self.brightness, "jitter": self.jitter})
        return config

    def call(self, images, training=True):
        if training:
            batch_size = tf.shape(images)[0]

            # Same for all colors
            brightness_scales = 1 + tf.random.uniform(
                (batch_size, 1, 1, 1), minval=-self.brightness, maxval=self.brightness
            )
            # Different for all colors
            jitter_matrices = tf.random.uniform(
                (batch_size, 1, 3, 3), minval=-self.jitter, maxval=self.jitter
            )

            color_transforms = (
                tf.eye(3, batch_shape=[batch_size, 1]) * brightness_scales
                + jitter_matrices
            )
            images = tf.clip_by_value(tf.matmul(images, color_transforms), 0, 1)
        return images

# %%
class GaussianBlur( tf.keras.__internal__.layers.BaseImageAugmentationLayer ):
    """Applies a Gaussian Blur with random sigma to an image.
    Args:
        kernel_size: int, 2 element tuple or 2 element list. x and y dimensions for
            the kernel used. If tuple or list, first element is used for the x dimension
            and second element is used for y dimension. If int, kernel will be squared.
        sigma: float, 2 element tuple or 2 element list. Interval in which sigma should
            be sampled from. If float, interval is going to be [0, float), else the
            first element represents the lower bound and the second element the upper
            bound of the sampling interval.
    """

    def __init__(self, kernel_size, sigma, **kwargs):
        super().__init__(**kwargs)
        self.kernel_size = kernel_size
        self.sigma = sigma

        if isinstance(kernel_size, (tuple, list)):
            self.x = kernel_size[0]
            self.y = kernel_size[1]
        else:
            if isinstance(kernel_size, int):
                self.x = self.y = kernel_size
            else:
                raise ValueError(
                    "`kernel_size` must be list, tuple or integer "
                    ", got {} ".format(type(self.kernel_size))
                )

        if isinstance(sigma, (tuple, list)):
            self.sigma_min = sigma[0]
            self.sigma_max = sigma[1]
        else:
            self.sigma_min = type(sigma)(0)
            self.sigma_max = sigma

        if not isinstance(self.sigma_min, type(self.sigma_max)):
            raise ValueError(
                "`sigma` must have lower bound and upper bound "
                "with same type, got {} and {}".format(
                    type(self.sigma_min), type(self.sigma_max)
                )
            )

        if self.sigma_max < self.sigma_min:
            raise ValueError(
                "`sigma` cannot have upper bound less than "
                "lower bound, got {}".format(sigma)
            )

        self._sigma_is_float = isinstance(self.sigma, float)
        if self._sigma_is_float:
            if not self.sigma_min >= 0.0:
                raise ValueError(
                    "`sigma` must be higher than 0"
                    "when is float, got {}".format(sigma)
                )

    def get_random_transformation(self, image=None, label=None, bounding_box=None):
        sigma = self.get_sigma()
        blur_v = GaussianBlur.get_kernel(sigma, self.y)
        blur_h = GaussianBlur.get_kernel(sigma, self.x)
        blur_v = tf.reshape(blur_v, [self.y, 1, 1, 1])
        blur_h = tf.reshape(blur_h, [1, self.x, 1, 1])
        return (blur_v, blur_h)

    def get_sigma(self):
        sigma = self._random_generator.random_uniform(
            shape=(), minval=self.sigma_min, maxval=self.sigma_max
        )
        return sigma

    def augment_image(self, image, transformation=None):

        image = tf.expand_dims(image, axis=0)

        num_channels = tf.shape(image)[-1]
        blur_v, blur_h = transformation
        blur_h = tf.tile(blur_h, [1, 1, num_channels, 1])
        blur_v = tf.tile(blur_v, [1, 1, num_channels, 1])
        blurred = tf.nn.depthwise_conv2d(
            image, blur_h, strides=[1, 1, 1, 1], padding="SAME"
        )
        blurred = tf.nn.depthwise_conv2d(
            blurred, blur_v, strides=[1, 1, 1, 1], padding="SAME"
        )

        return tf.squeeze(blurred, axis=0)

    @staticmethod
    def get_kernel(sigma, filter_size):
        x = tf.cast(
            tf.range(-filter_size // 2 + 1, filter_size // 2 + 1), dtype=tf.float32
        )
        blur_filter = tf.exp(
            -tf.pow(x, 2.0) / (2.0 * tf.pow(tf.cast(sigma, dtype=tf.float32), 2.0))
        )
        blur_filter /= tf.reduce_sum(blur_filter)
        return blur_filter

    def get_config(self):
        config = super().get_config()
        config.update({"sigma": self.sigma, "kernel_size": self.kernel_size})
        return config

# %% [markdown]
# ## Temporal Encoder Davinci

# %% [markdown]
# ## Create Davinci Train

# %%
pigs_train = ["1323", "1326", "1327", "1328"]
wounds = ["Wound_A", "Wound_B", "Wound_C", "Wound_D", "Wound_E", "Wound_F",
          "Wound_G", "Wound_H", "Wound_I", "Wound_J", "Wound_K", "Wound_L"]

# %%
from copy import deepcopy
# load patch train images
base_ = ''
imgs_quad = glob.glob("data/near_quad_tr=0.5/**/*.jpg",recursive=True)
data =  pd.DataFrame(columns=["image","wound","day","quadrant"])
for fn in imgs_quad:
    tmp = fn.split("/")
    img = fn
    day = tmp[2].split("_")[1]
    #print(tmp, day)
    img_id = tmp[3].split("_")
    #print(img_id)
    img_id = "_".join([img_id[2], img_id[3], img_id[4]])
    quadrant = img.split("_")[-2]
    #print(img_id,day, quadrant, img)
    data.loc[len(data.index)] = [img, img_id, day, quadrant]

test_data = data[data['wound'].str.contains("1324")].reset_index(drop=True)
train_data = data[~data['wound'].str.contains("1324")].reset_index(drop=True)

# %%
train_samples = []
train_label = []
count = 0
wounds = data['wound'].unique()
nump_sample = 3

for quadrant in ["00", "01","10","11"]:
    for wound in wounds:
        img_sample_df = train_data[ (train_data["quadrant"]==quadrant) & (train_data["wound"]==wound) ].groupby('day',group_keys=False).apply(lambda x:  x.sample(nump_sample,replace=False) if len(x) > nump_sample else x.sample(nump_sample,replace=True)).reset_index(drop=True)

        img_arr = np.array(img_sample_df["image"])
        img_arr = img_arr.reshape( len( img_sample_df['day'].unique() ), nump_sample)
        x = y = np.arange(0, len( img_sample_df['day'].unique() ), 1)
        combos = np.array(np.meshgrid(x, y)).T.reshape(-1, 2)
        drops = []

        for i in range(len(combos)):
            if combos[i][0] == combos[i][1]:
                drops.append(i)
        combos = np.delete(combos,drops,axis=0)
        for i in range(nump_sample):
            for j in range(i+1, nump_sample):
                for combo in combos:
                    img_1 = (img_arr[combo[0], i])
                    img_2 = (img_arr[combo[1], j])
                    train_samples.append((img_1,img_2))
                    train_label.append(1 if combo[0] > combo[1] else 0)
                    #print(img_1)
                    #print(img_2)
                    #print(label)
                    #print("")
                    count += 1

x_train =np.ndarray((count, 2, 128, 128, 3), dtype=np.float32)

y_train = np.array(train_label, dtype=np.int32)
idx = 0

for left_path, right_path in tqdm(train_samples):
    #im_l =
    #im_2 =
    x_train[idx,0,:,:,:] = img_to_array( Image.open(left_path) )
    x_train[idx,1,:,:,:] = img_to_array( Image.open(right_path) )
    idx += 1

print(f" {count} samples created.")


test_samples = []
test_label = []
count = 0
wounds = data['wound'].unique()
nump_sample = 3

for quadrant in ["00", "01","10","11"]:
    for wound in wounds:
        img_sample_df = test_data[ (test_data["quadrant"]==quadrant) & (test_data["wound"]==wound) ].groupby('day',group_keys=False).apply(lambda x:  x.sample(nump_sample,replace=False) if len(x) > nump_sample else x.sample(nump_sample,replace=True)).reset_index(drop=True)

        img_arr = np.array(img_sample_df["image"])
        img_arr = img_arr.reshape( len( img_sample_df['day'].unique() ), nump_sample)
        x = y = np.arange(0, len( img_sample_df['day'].unique() ), 1)
        combos = np.array(np.meshgrid(x, y)).T.reshape(-1, 2)
        drops = []

        for i in range(len(combos)):
            if combos[i][0] == combos[i][1]:
                drops.append(i)
        combos = np.delete(combos,drops,axis=0)
        for i in range(nump_sample):
            for j in range(i+1, nump_sample):
                for combo in combos:
                    img_1 = (img_arr[combo[0], i])
                    img_2 = (img_arr[combo[1], j])
                    test_samples.append((img_1,img_2))
                    test_label.append(1 if combo[0] > combo[1] else 0)
                    #print(img_1)
                    #print(img_2)
                    #print(label)
                    #print("")
                    count += 1

x_test =np.ndarray((count, 2, 128, 128, 3), dtype=np.float32)
y_test = np.array(test_label, dtype=np.int32)
idx = 0

for left_path, right_path in tqdm(test_samples):
    #im_l =
    #im_2 =
    x_test[idx,0,:,:,:] = img_to_array( Image.open(left_path) )
    x_test[idx,1,:,:,:] = img_to_array( Image.open(right_path) )
    idx += 1

print(f" {count} samples created.")
# Out:
#   0%|          | 0/14172 [00:00<?, ?it/s]
#  14172 samples created.
#   0%|          | 0/2856 [00:00<?, ?it/s]
#  2856 samples created.

# %%
idx = 0
for left_path, right_path in tqdm(test_samples):
    #im_l =
    #im_2 =
    x_test[idx,0,:,:,:] = deepcopy(img_to_array( Image.open(left_path).resize((128,128)) ))
    x_test[idx,1,:,:,:] = deepcopy(img_to_array( Image.open(right_path).resize((128,128)) ))
    idx += 1

print(f" {count} samples created.")
# Out:
#   0%|          | 0/2856 [00:00<?, ?it/s]
#  2856 samples created.

# %%
#with open('data/patch_train.npy', 'wb') as f:
#    np.save(f, x_train)
#    np.save(f, y_train)

#with open('data/patch_test.npy', 'wb') as f:
#    np.save(f, x_test)
#    np.save(f, y_test)

# %%
with open('data/patch_train.npy', 'rb') as f:
    x_train = np.load(f)
    y_train = np.load(f)

with open('data/patch_test.npy', 'rb') as f:
    x_test = np.load(f)
    y_test = np.load(f)

# %% [markdown]
# # Temporal Encoder

# %%
in_shape = (128, 128, 3)
latent_size = 16

# %%
base_model = DenseNet121(
    weights='imagenet',
    include_top=False,
    input_shape = in_shape
)

# %%
# This actually happens second than below
x = base_model.output
x = GlobalMaxPooling2D()(x) # should we do average pooling?
x = Dropout(0.5)(x) # should experiment with this
x = Dense(latent_size)(x)

feature_extractor = Model(inputs=base_model.input, outputs=x)

# %%
stddev = 0.1

# good cell to remember when getting funky with layers (augmentation)
img_a = Input(shape=in_shape)
img_b = Input(shape=in_shape)

x_a = RandomFlip("horizontal_and_vertical")(img_a)
x_a = RandomRotation(0.5, fill_mode='constant')(x_a)
x_a = tf.keras.layers.GaussianNoise(stddev)(x_a)
x_a = RandomContrast(0.5)(x_a)
x_a = GaussianBlur(kernel_size=(3, 3), sigma=(0, 2))(x_a)
#x_a = RandomColorDistortion()(x_a)

x_b = RandomFlip("horizontal_and_vertical")(img_b)
x_b = RandomRotation(0.5, fill_mode='constant')(x_b)
x_b = tf.keras.layers.GaussianNoise(stddev)(x_b)
x_b = RandomContrast(0.5)(x_b)
x_b = GaussianBlur(kernel_size=(3, 3), sigma=(0, 2))(x_b)
#x_b = RandomColorDistortion()(x_b)

x_a = densenet_preprocess(x_a)
x_b = densenet_preprocess(x_b)

features_a = feature_extractor(x_a)
features_b = feature_extractor(x_b)

concat = Concatenate()([features_a, features_b])

output = Dense(1, activation="sigmoid")(concat)
temporal_encoder = Model(inputs=[img_a, img_b], outputs=output)

# %%
temporal_encoder.compile(loss="binary_crossentropy",
                         optimizer=Adam(0.00075),
                         metrics=['accuracy'])

# %%
best_model_file = "./Saved Weights/HealNet_encoder_Michael_Nov5_GaussianBlur.h5"

earlystop = EarlyStopping(monitor = 'val_accuracy',
                          min_delta = 0,
                          patience = 5,
                          verbose = 1,
                          restore_best_weights = True)

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy',
                              factor = 0.1,
                              patience = 6,
                              min_lr = 0.000001,
                              verbose = 1)

tensor_board = tbCallBack = TensorBoard(log_dir = f'./logs/HealNet_encoder_device_patches',
                                        histogram_freq = 0,
                                        write_graph = True,
                                        write_images = False)


best_model = ModelCheckpoint(best_model_file,
                             monitor = 'val_accuracy',
                             mode = 'auto',
                             verbose = 1,
                             save_best_only = True)

callback_list = [reduce_lr, earlystop, best_model, tensor_board]

# %%
history_densenet = temporal_encoder.fit(
    x = [x_train[:,0], x_train[:,1]],
    y = y_train,
    validation_data = (([x_test[:,0], x_test[:,1]]), y_test),
    batch_size = 32,
    epochs = 20,
    verbose = 1,
    callbacks = callback_list
)
# Out:
# Epoch 1/20
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2 cause Input "contrast_factor" of op 'AdjustContrastv2' expected to be loop invariant.
# 1305/1305 [==============================] - ETA: 0s - loss: 0.8360 - accuracy: 0.6495
# Epoch 1: val_accuracy improved from -inf to 0.65270, saving model to ./Saved Weights/HealNet_encoder_Michael_Nov5_GaussianBlur.h5
# 1305/1305 [==============================] - 489s 347ms/step - loss: 0.8360 - accuracy: 0.6495 - val_loss: 0.5925 - val_accuracy: 0.6527 - lr: 7.5000e-04
# Epoch 2/20
# 1305/1305 [==============================] - ETA: 0s - loss: 0.5735 - accuracy: 0.7216
# Epoch 2: val_accuracy improved from 0.65270 to 0.68709, saving model to ./Saved Weights/HealNet_encoder_Michael_Nov5_GaussianBlur.h5
# 1305/1305 [==============================] - 438s 336ms/step - loss: 0.5735 - accuracy: 0.7216 - val_loss: 0.6076 - val_accuracy: 0.6871 - lr: 7.5000e-04
# Epoch 3/20
# 1305/1305 [==============================] - ETA: 0s - loss: 0.5081 - accuracy: 0.7507
# Epoch 3: val_accuracy did not improve from 0.68709
# 1305/1305 [==============================] - 436s 334ms/step - loss: 0.5081 - accuracy: 0.7507 - val_loss: 0.7128 - val_accuracy: 0.6330 - lr: 7.5000e-04
# Epoch 4/20
# 1305/1305 [==============================] - ETA: 0s - loss: 0.3966 - accuracy: 0.8182
# Epoch 4: val_accuracy did not improve from 0.68709
# 1305/1305 [==============================] - 436s 334ms/step - loss: 0.3966 - accuracy: 0.8182 - val_loss: 0.5862 - val_accuracy: 0.6708 - lr: 7.5000e-04
# Epoch 5/20
# 1305/1305 [==============================] - ETA: 0s - loss: 0.3239 - accuracy: 0.8600
# Epoch 5: val_accuracy did not improve from 0.68709
# 1305/1305 [==============================] - 437s 335ms/step - loss: 0.3239 - accuracy: 0.8600 - val_loss: 0.7564 - val_accuracy: 0.6621 - lr: 7.5000e-04
# Epoch 6/20
# 1305/1305 [==============================] - ETA: 0s - loss: 0.2947 - accuracy: 0.8742
# Epoch 6: val_accuracy did not improve from 0.68709
# 1305/1305 [==============================] - 438s 335ms/step - loss: 0.2947 - accuracy: 0.8742 - val_loss: 0.6119 - val_accuracy: 0.6665 - lr: 7.5000e-04
# Epoch 7/20
# 1305/1305 [==============================] - ETA: 0s - loss: 0.2639 - accuracy: 0.8881Restoring model weights from the end of the best epoch: 2.
#
# Epoch 7: val_accuracy did not improve from 0.68709
# 1305/1305 [==============================] - 438s 335ms/step - loss: 0.2639 - accuracy: 0.8881 - val_loss: 0.9815 - val_accuracy: 0.6459 - lr: 7.5000e-04
# Epoch 7: early stopping

# %%
history_densenet

# %%
# Save the weights
feature_extractor.save_weights('./Saved Weights/temporal_encoder_Michael_Nov5_GaussianBlur.h5')

# %%
base_model.save_weights('./Saved Weights/base_model_Michael_Nov5_GaussianBlur.h5')

# %%
#best_model_file = "cHealNet_encoder_davinci_patches_quadrant.h5"
#model = keras.models.load_model(best_model_file)

# %% [markdown]
# ## Get Embeddings

# %%
"""
# Get embeddings?
image_fns = glob.glob( "data/near_quad_tr=0.5/**/*.jpg" , recursive=True)
#print(direc + "**/*.jpg" )
#ratio = 1.0/255.0
imgs_ = np.ndarray((len(image_fns), 128, 128, 3), dtype=np.float32)
embeddings = np.ndarray((len(image_fns), 16), dtype=np.float32)
idx = 0
for fn in tqdm(image_fns):
    imgs_[idx,:,:,:] = img_to_array( Image.open(fn) )
"""
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-075b1d701ac3> in <cell line: 1>()
# ----> 1 image_fns = glob.glob( "data/near_quad_tr=0.5/**/*.jpg" , recursive=True)
#       2 #print(direc + "**/*.jpg" )
#       3 #ratio = 1.0/255.0
#       4 imgs_ = np.ndarray((len(image_fns), 128, 128, 3), dtype=np.float32)
#       5 embeddings = np.ndarray((len(image_fns), 16), dtype=np.float32)
#
# /usr/lib/python3.10/glob.py in glob(pathname, root_dir, dir_fd, recursive)
#      22     zero or more directories and subdirectories.
#      23     """
# ---> 24     return list(iglob(pathname, root_dir=root_dir, dir_fd=dir_fd, recursive=recursive))
#      25
#      26 def iglob(pathname, *, root_dir=None, dir_fd=None, recursive=False):
#
# /usr/lib/python3.10/glob.py in _iglob(pathname, root_dir, dir_fd, recursive, dironly)
#      84         glob_in_dir = _glob0
#      85     for dirname in dirs:
# ---> 86         for name in glob_in_dir(_join(root_dir, dirname), basename, dir_fd, dironly):
#      87             yield os.path.join(dirname, name)
#      88
#
# /usr/lib/python3.10/glob.py in _glob1(dirname, pattern, dir_fd, dironly)
#      92
#      93 def _glob1(dirname, pattern, dir_fd, dironly):
# ---> 94     names = _listdir(dirname, dir_fd, dironly)
#      95     if not _ishidden(pattern):
#      96         names = (x for x in names if not _ishidden(x))
#
# /usr/lib/python3.10/glob.py in _listdir(dirname, dir_fd, dironly)
#     162 def _listdir(dirname, dir_fd, dironly):
#     163     with contextlib.closing(_iterdir(dirname, dir_fd, dironly)) as it:
# --> 164         return list(it)
#     165
#     166 # Recursively yields relative pathnames inside a literal directory.
#
# /usr/lib/python3.10/glob.py in _iterdir(dirname, dir_fd, dironly)
#     147                 for entry in it:
#     148                     try:
# --> 149                         if not dironly or entry.is_dir():
#     150                             if fsencode is not None:
#     151                                 yield fsencode(entry.name)
#
# KeyboardInterrupt:

# %%
def get_feature_vectors(model, direc=''):
    features = []
    img_names = []
    image_fns = glob.glob( direc + "**/*.jpg" , recursive=True)
    print(len(image_fns))
    #print(direc + "**/*.jpg" )
    #ratio = 1.0/255.0
    for i in tqdm(image_fns):
        #fn =  i
        loaded_image = load_img(i).resize((128,128))
        image_data = img_to_array(loaded_image)
        loaded_image.close()
        #print(image_data.shape)
        #image_data =  # densenet hardcoded!
        #image_data = np.expand_dims(densenet_preprocess(image_data), axis=0) # adds batch dim
        feat = model.predict(np.expand_dims(densenet_preprocess(image_data), axis=0), verbose = 0).flatten()
        #feat = model(image_data, training=False).numpy()
        #print(feat.shape)
        #feat = feat.flatten()
        features.append(feat)
        img_names.append(i)

    return features, img_names

# %%
from copy import deepcopy
# load patch train images
base_ = '/content/drive/MyDrive/BETR_Summer23/data/Sep2_cleaned_control_images_Patch_Image/test_ctl_sep2_3x4_quad/'
imgs_quad = glob.glob(base_+'*.jpg')

#Create dataframe from images
count = 0
data =  pd.DataFrame(columns=["image","wound","day","quadrant"])
for fn in imgs_quad:
    tmp = fn.split("/")[-1].split("_")
    wound = "".join([tmp[1], tmp[3]]) # Exp-wound combined
    day = tmp[5]
    quad = tmp[7]
    data.loc[len(data.index)] = [fn, wound, day, quad]
    count += 1

imgs_list = [x.split("/")[-1] for x in list(data['image'])]
print(f"created dataframe of size {data.shape}...")

#load image combos into numpy arrays
x_train = np.ndarray((count, 128, 128, 3), dtype=np.float32)
idx=0

print(f"creating training set patch array...")
for left_path in tqdm(data['image']):
    x_train[idx,:,:,:] = deepcopy(img_to_array( Image.open(left_path).resize((128,128)) ))
    idx += 1


print(f" {len(idx+1)} sample pairs created.")
# Out:
# created dataframe of size (8087, 4)...
# creating training set patch array...
#   0%|          | 0/8087 [00:00<?, ?it/s]

# %%
base_ = '/content/drive/MyDrive/BETR_Summer23/data/Sep2_cleaned_control_images_Patch_Image/train_ctl_sep2_3x4_quad/'
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-1c076996c179> in <cell line: 7>()
#      10     day = tmp[5]
#      11     quad = tmp[7]
# ---> 12     data.loc[len(data.index)] = [fn, wound, day, quad]
#      13     count += 1
#      14 # Flow from directory with specified batch size and target image size
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     816
#     817         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 818         iloc._setitem_with_indexer(indexer, value, self.name)
#     819
#     820     def _validate_key(self, key, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1783
#    1784             if missing:
# -> 1785                 self._setitem_with_indexer_missing(indexer, value)
#    1786                 return
#    1787
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _setitem_with_indexer_missing(self, indexer, value)
#    2180                 self.obj._mgr = df._mgr
#    2181             else:
# -> 2182                 self.obj._mgr = self.obj._append(value)._mgr
#    2183             self.obj._maybe_update_cacher(clear=True)
#    2184
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _append(self, other, ignore_index, verify_integrity, sort)
#    9806             to_concat = [self, other]
#    9807
# -> 9808         result = concat(
#    9809             to_concat,
#    9810             ignore_index=ignore_index,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     379     )
#     380
# --> 381     return op.get_result()
#     382
#     383
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/concat.py in get_result(self)
#     614                 mgrs_indexers.append((obj._mgr, indexers))
#     615
# --> 616             new_data = concatenate_managers(
#     617                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     618             )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/concat.py in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     221                 #  we can use np.concatenate, which is more performant
#     222                 #  than concat_compat
# --> 223                 values = np.concatenate(vals, axis=1)
#     224             else:
#     225                 # TODO(EA2D): special-casing not needed with 2D EAs
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
feature_vectors, image_names = get_feature_vectors(feature_extractor, train_pth)
# Out:
# 39255
#   0%|          | 0/39255 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-73e692cfa3f0> in <cell line: 1>()
# ----> 1 feature_vectors, image_names = get_feature_vectors(feature_extractor, train_pth)
#
# <ipython-input-31-23f78ce03501> in get_feature_vectors(model, direc)
#       8     for i in tqdm(image_fns):
#       9         #fn =  i
# ---> 10         loaded_image = load_img(i).resize((128,128))
#      11         image_data = img_to_array(loaded_image)
#      12         loaded_image.close()
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     421             path = str(path.resolve())
#     422         with open(path, "rb") as f:
# --> 423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#     425         raise TypeError(
#
# KeyboardInterrupt:

# %%
#feature_vectors = np.array(feature_vectors )
#with open('data/davinci_feature_vectors.npy', 'wb') as f:
#    np.save(f, feature_vectors)
#    np.save(f, image_names)

# with open('data/davinci_feature_vectors.npy', 'rb') as f:
#    feature_vectors = np.load(f)
#    image_names = np.load(f)

# %%
#imbeddings = pd.DataFrame(columns=["image","quadrant", "num", "embedding"])
#for img in tqdm(image_names):
#    img_only = img.split("/")[-1]
#    quadrant = img_only.split("_")[1]
#    num = img_only.split("_")[2].split(".")[0]
#    imbeddings.loc[len(imbeddings.index)] = [img_only, quadrant, num, feature_vectors[len(imbeddings.index)]]
# Out:
#   0%|          | 0/19539 [00:00<?, ?it/s]

# %%
#imbeddings.to_csv("data/davinci_embeddings_quad.csv")

# %%
#imbeddings = pd.read_csv("data/davinci_embeddings_quad.csv")

# %%
"""
import re
img_name = []
embedding = []
for i in range( len( imbeddings["embedding"] ) ):
    if 0.0 in [float(x) for x in re.findall(r"[-+]?(?:\d*\.*\d+)", imbeddings["embedding"][i])]:
        print( re.findall(r"[-+]?(?:\d*\.*\d+)",imbeddings["embedding"][i]) )
        print(imbeddings["embedding"][i] )
    embedding.append( deepcopy( [ float(x) for x in re.findall(r"[-+]?(?:\d*\.*\d+)",imbeddings["embedding"][i]) ] ) )
    img_name.append(imbeddings['image'].loc[i])
    #print(np.fromstring( imbeddings["embedding"][i].strip(),sep="," ))
imbeddings['image'] = img_name
imbeddings["embedding"] = embedding
"""
# Out:
# '\nimport re\nimg_name = []\nembedding = []\nfor i in range( len( imbeddings["embedding"] ) ):\n    if 0.0 in [float(x) for x in re.findall(r"[-+]?(?:\\d*\\.*\\d+)", imbeddings["embedding"][i])]:\n        print( re.findall(r"[-+]?(?:\\d*\\.*\\d+)",imbeddings["embedding"][i]) )\n        print(imbeddings["embedding"][i] )\n    embedding.append( deepcopy( [ float(x) for x in re.findall(r"[-+]?(?:\\d*\\.*\\d+)",imbeddings["embedding"][i]) ] ) )\n    img_name.append(imbeddings[\'image\'].loc[i])\n    #print(np.fromstring( imbeddings["embedding"][i].strip(),sep="," ))\n'

# %% [markdown]
# #### Patch Classification

# %%
# The code I used to combine the 16-dim latents
# Don't need for now, this is quadrant model combination classification
combined_idx = 0
combined_dict = {}
for i in range(len(imbeddings)):
    img_orig = imbeddings.loc[i]["image"]
    img_orig = img_orig.split("_")[0]+".jpg"
    quad = imbeddings.loc[i]["quadrant"]
    if img_orig not in combined_dict.keys():
        combined_dict[img_orig] = {}
    if quad not in combined_dict[img_orig].keys():
        combined_dict[img_orig][quad] = deepcopy(imbeddings.loc[i]['embedding'])
        #print(len(combined_dict[img_orig][quad]))
    else:
        #print(len(combined_dict[img_orig][quad]))
        #print(type(imbeddings.loc[i]['embedding']) )
        c = np.concatenate((combined_dict[img_orig][quad],imbeddings.loc[i]['embedding']))
        combined_dict[img_orig][quad] = deepcopy(c)
        #if img_orig == '3J6A1980.jpg':
        #    print(c)
        #combined_dict[img_orig][quad].extend(deepcopy(imbeddings.loc[i]['embedding'] ))

combined_final = {}
q0=q1=q2=q3=0
tmp = np.zeros((len(combined_dict.keys()), 16*12))
for i, img_ in enumerate(combined_dict.keys()):

    for quad in combined_dict[img_]:
        if len(combined_dict[img_][quad]) < 48:
            #print(len(combined_dict[img_][quad]))
            new = np.pad(combined_dict[img_][quad], (48-len(combined_dict[img_][quad]))//2)
        else:
            new = combined_dict[img_][quad]

        if quad == "00":
            tmp[i,0:48]= deepcopy(new)
            #q0 += 1
        elif quad == "01":
            tmp[i,48:96]= deepcopy(new)
            q1 += 1
        elif quad == "10":
            tmp[i,96:144]= deepcopy(new)
            q2 += 1
        elif quad == "11":
            tmp[i,144:192]= deepcopy(new)
            q2 += 1
    #combined_final[img_] = deepcopy(tmp)

# %%
#combined_embeddings.to_csv('data/combined_embeddings.csv')

# %%
folders = {}
for img in labels['image']:
    #if img.split(".")[0] == '3J6A3849':
    #    continue
    for fn in imgs_fn:
        if img in fn:
            folder = fn.split("/")[-2]
            if folder not in folders.keys():
                folders[folder] = labels['final_label'][labels['image'] == img].values[0]

# %%
corrected_img = []
for img in imgs_fn:
    if '3J6A3849' not in img:
        corrected_img.append(img)

davinci_labels = []
for fn in corrected_img:
    folder = fn.split("/")[-2]
    davinci_labels.append(folders[folder])

# %%
#davinci_embedding_data
# with open('data/davinci_embedding_data.npy', 'wb') as f:
#    np.save(f, np.array(corrected_img)) # original file structure: wound, day, etc
#    np.save(f, np.array(list(combined_dict.keys()))) # original image names
#    np.save(f, np.array(davinci_labels)) # labels for original images
#    np.save(f, tmp) # embeddings
with open('data/davinci_embedding_data.npy', 'rb') as f:
    corrected_img = np.load(f) # original file structure: wound, day, etc
    dict_keys = np.load(f) # original image names
    davinci_labels = np.load(f) # labels for original images
    tmp = np.load(f) # embeddings

# %%
stage_ ={'Hemostasis':0, 'Inflammatory': 1, 'Proliferative':2, 'Maturation':3}

# %%
test_index = []
train_index = []
for i,img in enumerate(corrected_img):
    if "1325" in img:
        test_index.append(i)
    else:
        train_index.append(i)

davinci_test_labels = np.array( [stage_[x] for x in np.array(davinci_labels)[test_index] ] )
davinci_test = tmp[test_index]

davinci_train_labels =  np.array( [ stage_[x] for x in np.array(davinci_labels)[train_index] ] )
davinci_train = tmp[train_index]

# %%
# Embedding Classifier

# %%
# Create a Normalization layer and set its internal state using the training data
normalizer = layers.Normalization()
normalizer.adapt(davinci_train)

# %%
inputs = keras.Input(shape=(192,))
x = normalizer(inputs)
#x = layers.Dense(64, activation="relu")(x)
x = layers.Dense(128, activation="relu")(x)
x = Dropout(0.3)(x) # should experiment with this
x = layers.Dense(16, activation="relu")(x)
outputs = layers.Dense(4, activation="softmax")(x)
combined_embedding_model = keras.Model(inputs=inputs, outputs=outputs, name="combined_embedding_model")

# %%
combined_embedding_model.compile(loss="sparse_categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.000075), metrics=['accuracy'])

# %%
best_model_file = "./Saved Weights/combined_embedding_model.h5"

earlystop = EarlyStopping(monitor = 'val_accuracy',
                          min_delta = 0,
                          patience = 250,
                          verbose = 1,
                          restore_best_weights = True)

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy',
                              factor = 0.1,
                              patience = 6,
                              min_lr = 0.000001,
                              verbose = 1)

tensor_board = tbCallBack = TensorBoard(log_dir = f'./logs/HealNet_encoder_device_patches',
                                        histogram_freq = 0,
                                        write_graph = True,
                                        write_images = False)


best_model = ModelCheckpoint(best_model_file,
                             monitor = 'val_accuracy',
                             mode = 'auto',
                             verbose = 1,
                             save_best_only = True)

callback_list = [reduce_lr, earlystop, best_model, tensor_board]

# %%
history_densenet = combined_embedding_model.fit(
    x = davinci_train,
    y = davinci_train_labels,
    validation_data = (davinci_test, davinci_test_labels),
    batch_size = 32,
    epochs = 5000,
    verbose = 1,
    #callbacks = callback_list
)
# Out:
# Streaming output truncated to the last 5000 lines.
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8276 - accuracy: 0.6320 - val_loss: 1.5541 - val_accuracy: 0.3686
# Epoch 2502/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8389 - accuracy: 0.6087 - val_loss: 1.5585 - val_accuracy: 0.3759
# Epoch 2503/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8419 - accuracy: 0.6102 - val_loss: 1.5674 - val_accuracy: 0.3686
# Epoch 2504/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8278 - accuracy: 0.6153 - val_loss: 1.5715 - val_accuracy: 0.3723
# Epoch 2505/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8354 - accuracy: 0.6167 - val_loss: 1.5651 - val_accuracy: 0.3759
# Epoch 2506/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8347 - accuracy: 0.6145 - val_loss: 1.5588 - val_accuracy: 0.3796
# Epoch 2507/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8179 - accuracy: 0.6349 - val_loss: 1.5752 - val_accuracy: 0.3759
# Epoch 2508/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8254 - accuracy: 0.6233 - val_loss: 1.5645 - val_accuracy: 0.3759
# Epoch 2509/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8523 - accuracy: 0.6051 - val_loss: 1.5701 - val_accuracy: 0.3759
# Epoch 2510/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8201 - accuracy: 0.6153 - val_loss: 1.5826 - val_accuracy: 0.3723
# Epoch 2511/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8307 - accuracy: 0.6247 - val_loss: 1.5863 - val_accuracy: 0.3650
# Epoch 2512/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8257 - accuracy: 0.6225 - val_loss: 1.5789 - val_accuracy: 0.3759
# Epoch 2513/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8214 - accuracy: 0.6225 - val_loss: 1.5813 - val_accuracy: 0.3686
# Epoch 2514/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8276 - accuracy: 0.6276 - val_loss: 1.5660 - val_accuracy: 0.3759
# Epoch 2515/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8288 - accuracy: 0.6233 - val_loss: 1.5611 - val_accuracy: 0.3832
# Epoch 2516/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8254 - accuracy: 0.6211 - val_loss: 1.5807 - val_accuracy: 0.3723
# Epoch 2517/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8300 - accuracy: 0.6080 - val_loss: 1.5738 - val_accuracy: 0.3759
# Epoch 2518/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8111 - accuracy: 0.6349 - val_loss: 1.5782 - val_accuracy: 0.3686
# Epoch 2519/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8418 - accuracy: 0.6138 - val_loss: 1.5755 - val_accuracy: 0.3686
# Epoch 2520/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8397 - accuracy: 0.6313 - val_loss: 1.5805 - val_accuracy: 0.3686
# Epoch 2521/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8447 - accuracy: 0.6167 - val_loss: 1.5812 - val_accuracy: 0.3686
# Epoch 2522/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8221 - accuracy: 0.6233 - val_loss: 1.5800 - val_accuracy: 0.3832
# Epoch 2523/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8425 - accuracy: 0.6233 - val_loss: 1.5755 - val_accuracy: 0.3869
# Epoch 2524/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8421 - accuracy: 0.6007 - val_loss: 1.5910 - val_accuracy: 0.3796
# Epoch 2525/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8327 - accuracy: 0.6080 - val_loss: 1.5845 - val_accuracy: 0.3650
# Epoch 2526/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8495 - accuracy: 0.6051 - val_loss: 1.5732 - val_accuracy: 0.3650
# Epoch 2527/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8331 - accuracy: 0.6175 - val_loss: 1.5672 - val_accuracy: 0.3832
# Epoch 2528/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8122 - accuracy: 0.6167 - val_loss: 1.5615 - val_accuracy: 0.3832
# Epoch 2529/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8275 - accuracy: 0.6218 - val_loss: 1.5641 - val_accuracy: 0.3869
# Epoch 2530/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8243 - accuracy: 0.6327 - val_loss: 1.5658 - val_accuracy: 0.3796
# Epoch 2531/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8469 - accuracy: 0.6044 - val_loss: 1.5726 - val_accuracy: 0.3723
# Epoch 2532/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8221 - accuracy: 0.6255 - val_loss: 1.5671 - val_accuracy: 0.3650
# Epoch 2533/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8342 - accuracy: 0.6116 - val_loss: 1.5707 - val_accuracy: 0.3759
# Epoch 2534/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8262 - accuracy: 0.6255 - val_loss: 1.5846 - val_accuracy: 0.3723
# Epoch 2535/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8211 - accuracy: 0.6327 - val_loss: 1.5742 - val_accuracy: 0.3796
# Epoch 2536/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8360 - accuracy: 0.6116 - val_loss: 1.5763 - val_accuracy: 0.3759
# Epoch 2537/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8273 - accuracy: 0.6327 - val_loss: 1.5778 - val_accuracy: 0.3759
# Epoch 2538/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8248 - accuracy: 0.6218 - val_loss: 1.5859 - val_accuracy: 0.3723
# Epoch 2539/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8271 - accuracy: 0.6291 - val_loss: 1.5644 - val_accuracy: 0.3832
# Epoch 2540/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8197 - accuracy: 0.6276 - val_loss: 1.5925 - val_accuracy: 0.3686
# Epoch 2541/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8330 - accuracy: 0.6182 - val_loss: 1.5858 - val_accuracy: 0.3686
# Epoch 2542/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8184 - accuracy: 0.6509 - val_loss: 1.5799 - val_accuracy: 0.3723
# Epoch 2543/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8243 - accuracy: 0.6349 - val_loss: 1.5879 - val_accuracy: 0.3686
# Epoch 2544/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8252 - accuracy: 0.6029 - val_loss: 1.5731 - val_accuracy: 0.3832
# Epoch 2545/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8336 - accuracy: 0.6167 - val_loss: 1.5821 - val_accuracy: 0.3723
# Epoch 2546/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8286 - accuracy: 0.6298 - val_loss: 1.5880 - val_accuracy: 0.3686
# Epoch 2547/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8302 - accuracy: 0.6204 - val_loss: 1.5732 - val_accuracy: 0.3723
# Epoch 2548/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8276 - accuracy: 0.6196 - val_loss: 1.5831 - val_accuracy: 0.3723
# Epoch 2549/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8240 - accuracy: 0.6313 - val_loss: 1.5735 - val_accuracy: 0.3832
# Epoch 2550/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8318 - accuracy: 0.6182 - val_loss: 1.5709 - val_accuracy: 0.3832
# Epoch 2551/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8099 - accuracy: 0.6284 - val_loss: 1.5755 - val_accuracy: 0.3832
# Epoch 2552/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8327 - accuracy: 0.6196 - val_loss: 1.5704 - val_accuracy: 0.3650
# Epoch 2553/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8353 - accuracy: 0.6145 - val_loss: 1.5781 - val_accuracy: 0.3686
# Epoch 2554/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8479 - accuracy: 0.6204 - val_loss: 1.5778 - val_accuracy: 0.3686
# Epoch 2555/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8245 - accuracy: 0.6095 - val_loss: 1.5677 - val_accuracy: 0.3832
# Epoch 2556/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8238 - accuracy: 0.6240 - val_loss: 1.5815 - val_accuracy: 0.3686
# Epoch 2557/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8328 - accuracy: 0.6211 - val_loss: 1.5779 - val_accuracy: 0.3759
# Epoch 2558/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8256 - accuracy: 0.6196 - val_loss: 1.5949 - val_accuracy: 0.3723
# Epoch 2559/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8365 - accuracy: 0.6175 - val_loss: 1.5964 - val_accuracy: 0.3650
# Epoch 2560/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8351 - accuracy: 0.6189 - val_loss: 1.5866 - val_accuracy: 0.3723
# Epoch 2561/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8345 - accuracy: 0.6204 - val_loss: 1.5969 - val_accuracy: 0.3723
# Epoch 2562/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8344 - accuracy: 0.6196 - val_loss: 1.5797 - val_accuracy: 0.3869
# Epoch 2563/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8283 - accuracy: 0.6124 - val_loss: 1.5854 - val_accuracy: 0.3759
# Epoch 2564/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8232 - accuracy: 0.6415 - val_loss: 1.5815 - val_accuracy: 0.3759
# Epoch 2565/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8232 - accuracy: 0.6320 - val_loss: 1.5843 - val_accuracy: 0.3759
# Epoch 2566/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8513 - accuracy: 0.6095 - val_loss: 1.5825 - val_accuracy: 0.3869
# Epoch 2567/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8339 - accuracy: 0.6015 - val_loss: 1.5816 - val_accuracy: 0.3905
# Epoch 2568/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8314 - accuracy: 0.6247 - val_loss: 1.5909 - val_accuracy: 0.3759
# Epoch 2569/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8391 - accuracy: 0.6182 - val_loss: 1.5778 - val_accuracy: 0.3905
# Epoch 2570/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8157 - accuracy: 0.6269 - val_loss: 1.5732 - val_accuracy: 0.3869
# Epoch 2571/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8175 - accuracy: 0.6269 - val_loss: 1.5977 - val_accuracy: 0.3723
# Epoch 2572/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8243 - accuracy: 0.6204 - val_loss: 1.5904 - val_accuracy: 0.3686
# Epoch 2573/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8270 - accuracy: 0.6305 - val_loss: 1.5894 - val_accuracy: 0.3796
# Epoch 2574/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8203 - accuracy: 0.6240 - val_loss: 1.5839 - val_accuracy: 0.3723
# Epoch 2575/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8450 - accuracy: 0.6065 - val_loss: 1.5779 - val_accuracy: 0.3832
# Epoch 2576/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8286 - accuracy: 0.6255 - val_loss: 1.5910 - val_accuracy: 0.3759
# Epoch 2577/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8353 - accuracy: 0.6247 - val_loss: 1.5887 - val_accuracy: 0.3796
# Epoch 2578/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8260 - accuracy: 0.6255 - val_loss: 1.5843 - val_accuracy: 0.3832
# Epoch 2579/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8415 - accuracy: 0.6095 - val_loss: 1.5858 - val_accuracy: 0.3832
# Epoch 2580/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8323 - accuracy: 0.6276 - val_loss: 1.5920 - val_accuracy: 0.3650
# Epoch 2581/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8168 - accuracy: 0.6218 - val_loss: 1.5857 - val_accuracy: 0.3759
# Epoch 2582/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8327 - accuracy: 0.6102 - val_loss: 1.5929 - val_accuracy: 0.3832
# Epoch 2583/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8162 - accuracy: 0.6240 - val_loss: 1.5838 - val_accuracy: 0.3686
# Epoch 2584/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8248 - accuracy: 0.6138 - val_loss: 1.5838 - val_accuracy: 0.3759
# Epoch 2585/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8227 - accuracy: 0.6131 - val_loss: 1.5862 - val_accuracy: 0.3832
# Epoch 2586/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8256 - accuracy: 0.6313 - val_loss: 1.5911 - val_accuracy: 0.3796
# Epoch 2587/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8442 - accuracy: 0.6124 - val_loss: 1.5831 - val_accuracy: 0.3723
# Epoch 2588/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8356 - accuracy: 0.6109 - val_loss: 1.5852 - val_accuracy: 0.3759
# Epoch 2589/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8244 - accuracy: 0.6327 - val_loss: 1.5890 - val_accuracy: 0.3796
# Epoch 2590/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8296 - accuracy: 0.6189 - val_loss: 1.5813 - val_accuracy: 0.3686
# Epoch 2591/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8304 - accuracy: 0.6305 - val_loss: 1.5833 - val_accuracy: 0.3832
# Epoch 2592/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8378 - accuracy: 0.6269 - val_loss: 1.5804 - val_accuracy: 0.3869
# Epoch 2593/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8136 - accuracy: 0.6298 - val_loss: 1.5837 - val_accuracy: 0.3759
# Epoch 2594/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8428 - accuracy: 0.6015 - val_loss: 1.5834 - val_accuracy: 0.3796
# Epoch 2595/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8273 - accuracy: 0.6291 - val_loss: 1.5664 - val_accuracy: 0.3869
# Epoch 2596/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8181 - accuracy: 0.6247 - val_loss: 1.5656 - val_accuracy: 0.3942
# Epoch 2597/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8198 - accuracy: 0.6247 - val_loss: 1.5803 - val_accuracy: 0.3796
# Epoch 2598/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8283 - accuracy: 0.6189 - val_loss: 1.5798 - val_accuracy: 0.3796
# Epoch 2599/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8329 - accuracy: 0.6211 - val_loss: 1.5844 - val_accuracy: 0.3723
# Epoch 2600/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8171 - accuracy: 0.6269 - val_loss: 1.5855 - val_accuracy: 0.3796
# Epoch 2601/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8265 - accuracy: 0.6320 - val_loss: 1.5855 - val_accuracy: 0.3869
# Epoch 2602/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8216 - accuracy: 0.6247 - val_loss: 1.5785 - val_accuracy: 0.3759
# Epoch 2603/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8422 - accuracy: 0.6145 - val_loss: 1.5841 - val_accuracy: 0.3869
# Epoch 2604/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8237 - accuracy: 0.6160 - val_loss: 1.5793 - val_accuracy: 0.3759
# Epoch 2605/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8296 - accuracy: 0.6218 - val_loss: 1.5939 - val_accuracy: 0.3759
# Epoch 2606/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8271 - accuracy: 0.6276 - val_loss: 1.5764 - val_accuracy: 0.3796
# Epoch 2607/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8348 - accuracy: 0.6255 - val_loss: 1.5848 - val_accuracy: 0.3832
# Epoch 2608/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8287 - accuracy: 0.6371 - val_loss: 1.5843 - val_accuracy: 0.3869
# Epoch 2609/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8253 - accuracy: 0.6124 - val_loss: 1.5927 - val_accuracy: 0.3869
# Epoch 2610/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8324 - accuracy: 0.6247 - val_loss: 1.5929 - val_accuracy: 0.3759
# Epoch 2611/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8234 - accuracy: 0.6196 - val_loss: 1.5942 - val_accuracy: 0.3869
# Epoch 2612/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8210 - accuracy: 0.6225 - val_loss: 1.5747 - val_accuracy: 0.3869
# Epoch 2613/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8311 - accuracy: 0.6160 - val_loss: 1.5735 - val_accuracy: 0.3796
# Epoch 2614/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8363 - accuracy: 0.6225 - val_loss: 1.5791 - val_accuracy: 0.3759
# Epoch 2615/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8324 - accuracy: 0.6262 - val_loss: 1.5755 - val_accuracy: 0.3686
# Epoch 2616/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8271 - accuracy: 0.6124 - val_loss: 1.5809 - val_accuracy: 0.3796
# Epoch 2617/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8479 - accuracy: 0.6175 - val_loss: 1.5782 - val_accuracy: 0.3796
# Epoch 2618/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8169 - accuracy: 0.6233 - val_loss: 1.5805 - val_accuracy: 0.3832
# Epoch 2619/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8291 - accuracy: 0.6225 - val_loss: 1.5820 - val_accuracy: 0.3832
# Epoch 2620/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8469 - accuracy: 0.6218 - val_loss: 1.5734 - val_accuracy: 0.3832
# Epoch 2621/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8157 - accuracy: 0.6393 - val_loss: 1.5807 - val_accuracy: 0.3796
# Epoch 2622/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8315 - accuracy: 0.6298 - val_loss: 1.5751 - val_accuracy: 0.3832
# Epoch 2623/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8287 - accuracy: 0.6102 - val_loss: 1.5837 - val_accuracy: 0.3796
# Epoch 2624/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8275 - accuracy: 0.6247 - val_loss: 1.5970 - val_accuracy: 0.3723
# Epoch 2625/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8123 - accuracy: 0.6356 - val_loss: 1.5940 - val_accuracy: 0.3650
# Epoch 2626/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8257 - accuracy: 0.6153 - val_loss: 1.5769 - val_accuracy: 0.3869
# Epoch 2627/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8218 - accuracy: 0.6385 - val_loss: 1.5885 - val_accuracy: 0.3796
# Epoch 2628/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8107 - accuracy: 0.6262 - val_loss: 1.5993 - val_accuracy: 0.3832
# Epoch 2629/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8349 - accuracy: 0.6145 - val_loss: 1.5982 - val_accuracy: 0.3723
# Epoch 2630/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8172 - accuracy: 0.6327 - val_loss: 1.5942 - val_accuracy: 0.3832
# Epoch 2631/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8320 - accuracy: 0.6131 - val_loss: 1.6006 - val_accuracy: 0.3723
# Epoch 2632/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8172 - accuracy: 0.6240 - val_loss: 1.5877 - val_accuracy: 0.3650
# Epoch 2633/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8362 - accuracy: 0.6262 - val_loss: 1.5819 - val_accuracy: 0.3650
# Epoch 2634/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8274 - accuracy: 0.6160 - val_loss: 1.5909 - val_accuracy: 0.3686
# Epoch 2635/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8203 - accuracy: 0.6378 - val_loss: 1.5914 - val_accuracy: 0.3759
# Epoch 2636/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8364 - accuracy: 0.6065 - val_loss: 1.5987 - val_accuracy: 0.3832
# Epoch 2637/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8269 - accuracy: 0.6335 - val_loss: 1.5876 - val_accuracy: 0.3723
# Epoch 2638/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8324 - accuracy: 0.6160 - val_loss: 1.5849 - val_accuracy: 0.3723
# Epoch 2639/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8357 - accuracy: 0.6167 - val_loss: 1.5737 - val_accuracy: 0.3796
# Epoch 2640/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8480 - accuracy: 0.6233 - val_loss: 1.5905 - val_accuracy: 0.3759
# Epoch 2641/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8349 - accuracy: 0.6240 - val_loss: 1.5864 - val_accuracy: 0.3796
# Epoch 2642/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8253 - accuracy: 0.6247 - val_loss: 1.5965 - val_accuracy: 0.3686
# Epoch 2643/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8158 - accuracy: 0.6211 - val_loss: 1.6070 - val_accuracy: 0.3650
# Epoch 2644/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8011 - accuracy: 0.6385 - val_loss: 1.5852 - val_accuracy: 0.3796
# Epoch 2645/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8197 - accuracy: 0.6313 - val_loss: 1.5870 - val_accuracy: 0.3759
# Epoch 2646/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8174 - accuracy: 0.6189 - val_loss: 1.5825 - val_accuracy: 0.3723
# Epoch 2647/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8424 - accuracy: 0.6087 - val_loss: 1.5779 - val_accuracy: 0.3796
# Epoch 2648/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8309 - accuracy: 0.6240 - val_loss: 1.5842 - val_accuracy: 0.3723
# Epoch 2649/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8253 - accuracy: 0.6196 - val_loss: 1.5867 - val_accuracy: 0.3723
# Epoch 2650/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8314 - accuracy: 0.6305 - val_loss: 1.5835 - val_accuracy: 0.3759
# Epoch 2651/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8063 - accuracy: 0.6364 - val_loss: 1.5756 - val_accuracy: 0.3832
# Epoch 2652/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8330 - accuracy: 0.6313 - val_loss: 1.5772 - val_accuracy: 0.3869
# Epoch 2653/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8200 - accuracy: 0.6465 - val_loss: 1.5794 - val_accuracy: 0.3796
# Epoch 2654/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8266 - accuracy: 0.6276 - val_loss: 1.5901 - val_accuracy: 0.3723
# Epoch 2655/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8217 - accuracy: 0.6225 - val_loss: 1.5761 - val_accuracy: 0.3759
# Epoch 2656/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8330 - accuracy: 0.6102 - val_loss: 1.5831 - val_accuracy: 0.3832
# Epoch 2657/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8266 - accuracy: 0.6160 - val_loss: 1.5865 - val_accuracy: 0.3796
# Epoch 2658/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8200 - accuracy: 0.6255 - val_loss: 1.5863 - val_accuracy: 0.3759
# Epoch 2659/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7984 - accuracy: 0.6262 - val_loss: 1.5895 - val_accuracy: 0.3686
# Epoch 2660/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8483 - accuracy: 0.6095 - val_loss: 1.5725 - val_accuracy: 0.3832
# Epoch 2661/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8163 - accuracy: 0.6313 - val_loss: 1.5881 - val_accuracy: 0.3759
# Epoch 2662/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8042 - accuracy: 0.6364 - val_loss: 1.5654 - val_accuracy: 0.3540
# Epoch 2663/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8242 - accuracy: 0.6196 - val_loss: 1.5604 - val_accuracy: 0.3759
# Epoch 2664/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8377 - accuracy: 0.6196 - val_loss: 1.5774 - val_accuracy: 0.3759
# Epoch 2665/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8292 - accuracy: 0.6160 - val_loss: 1.5714 - val_accuracy: 0.3832
# Epoch 2666/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8200 - accuracy: 0.6233 - val_loss: 1.5732 - val_accuracy: 0.3832
# Epoch 2667/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8260 - accuracy: 0.6204 - val_loss: 1.5844 - val_accuracy: 0.3832
# Epoch 2668/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8409 - accuracy: 0.6095 - val_loss: 1.5757 - val_accuracy: 0.3796
# Epoch 2669/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8322 - accuracy: 0.6262 - val_loss: 1.5885 - val_accuracy: 0.3832
# Epoch 2670/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8296 - accuracy: 0.6167 - val_loss: 1.5768 - val_accuracy: 0.3796
# Epoch 2671/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8281 - accuracy: 0.6116 - val_loss: 1.5936 - val_accuracy: 0.3796
# Epoch 2672/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8258 - accuracy: 0.6211 - val_loss: 1.5893 - val_accuracy: 0.3759
# Epoch 2673/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8325 - accuracy: 0.6233 - val_loss: 1.5870 - val_accuracy: 0.3686
# Epoch 2674/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8225 - accuracy: 0.6116 - val_loss: 1.5922 - val_accuracy: 0.3723
# Epoch 2675/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8154 - accuracy: 0.6240 - val_loss: 1.5812 - val_accuracy: 0.3650
# Epoch 2676/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8359 - accuracy: 0.6160 - val_loss: 1.5763 - val_accuracy: 0.3759
# Epoch 2677/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8360 - accuracy: 0.6211 - val_loss: 1.5833 - val_accuracy: 0.3832
# Epoch 2678/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8268 - accuracy: 0.6356 - val_loss: 1.5964 - val_accuracy: 0.3723
# Epoch 2679/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8243 - accuracy: 0.6145 - val_loss: 1.5957 - val_accuracy: 0.3832
# Epoch 2680/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8293 - accuracy: 0.6116 - val_loss: 1.5937 - val_accuracy: 0.3796
# Epoch 2681/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8001 - accuracy: 0.6385 - val_loss: 1.5921 - val_accuracy: 0.3796
# Epoch 2682/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8259 - accuracy: 0.6138 - val_loss: 1.5938 - val_accuracy: 0.3759
# Epoch 2683/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8403 - accuracy: 0.6073 - val_loss: 1.6080 - val_accuracy: 0.3723
# Epoch 2684/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8385 - accuracy: 0.6182 - val_loss: 1.5978 - val_accuracy: 0.3759
# Epoch 2685/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8188 - accuracy: 0.6298 - val_loss: 1.6003 - val_accuracy: 0.3650
# Epoch 2686/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8097 - accuracy: 0.6269 - val_loss: 1.5970 - val_accuracy: 0.3686
# Epoch 2687/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7930 - accuracy: 0.6240 - val_loss: 1.5883 - val_accuracy: 0.3759
# Epoch 2688/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8061 - accuracy: 0.6313 - val_loss: 1.5790 - val_accuracy: 0.3686
# Epoch 2689/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8131 - accuracy: 0.6240 - val_loss: 1.5825 - val_accuracy: 0.3796
# Epoch 2690/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7980 - accuracy: 0.6393 - val_loss: 1.5864 - val_accuracy: 0.3759
# Epoch 2691/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8140 - accuracy: 0.6378 - val_loss: 1.5925 - val_accuracy: 0.3650
# Epoch 2692/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8435 - accuracy: 0.6182 - val_loss: 1.5926 - val_accuracy: 0.3577
# Epoch 2693/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8287 - accuracy: 0.6305 - val_loss: 1.5877 - val_accuracy: 0.3832
# Epoch 2694/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8347 - accuracy: 0.6327 - val_loss: 1.5879 - val_accuracy: 0.3832
# Epoch 2695/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8088 - accuracy: 0.6385 - val_loss: 1.5965 - val_accuracy: 0.3869
# Epoch 2696/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8343 - accuracy: 0.6204 - val_loss: 1.6057 - val_accuracy: 0.3832
# Epoch 2697/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8205 - accuracy: 0.6393 - val_loss: 1.5846 - val_accuracy: 0.3796
# Epoch 2698/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8417 - accuracy: 0.6189 - val_loss: 1.5889 - val_accuracy: 0.3759
# Epoch 2699/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8258 - accuracy: 0.6233 - val_loss: 1.5879 - val_accuracy: 0.3869
# Epoch 2700/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8228 - accuracy: 0.6284 - val_loss: 1.5817 - val_accuracy: 0.3686
# Epoch 2701/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8325 - accuracy: 0.6269 - val_loss: 1.5824 - val_accuracy: 0.3759
# Epoch 2702/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8244 - accuracy: 0.6284 - val_loss: 1.5840 - val_accuracy: 0.3796
# Epoch 2703/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8312 - accuracy: 0.6247 - val_loss: 1.5744 - val_accuracy: 0.3650
# Epoch 2704/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8209 - accuracy: 0.6211 - val_loss: 1.5891 - val_accuracy: 0.3723
# Epoch 2705/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8226 - accuracy: 0.6349 - val_loss: 1.5848 - val_accuracy: 0.3796
# Epoch 2706/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8355 - accuracy: 0.6225 - val_loss: 1.5933 - val_accuracy: 0.3832
# Epoch 2707/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8175 - accuracy: 0.6182 - val_loss: 1.5985 - val_accuracy: 0.3759
# Epoch 2708/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8222 - accuracy: 0.6305 - val_loss: 1.5942 - val_accuracy: 0.3796
# Epoch 2709/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8286 - accuracy: 0.6247 - val_loss: 1.5992 - val_accuracy: 0.3686
# Epoch 2710/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8108 - accuracy: 0.6385 - val_loss: 1.6040 - val_accuracy: 0.3650
# Epoch 2711/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8339 - accuracy: 0.6145 - val_loss: 1.5932 - val_accuracy: 0.3869
# Epoch 2712/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8378 - accuracy: 0.6153 - val_loss: 1.6015 - val_accuracy: 0.3723
# Epoch 2713/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8237 - accuracy: 0.6320 - val_loss: 1.5784 - val_accuracy: 0.3723
# Epoch 2714/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8264 - accuracy: 0.6189 - val_loss: 1.5839 - val_accuracy: 0.3613
# Epoch 2715/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8297 - accuracy: 0.6153 - val_loss: 1.5893 - val_accuracy: 0.3686
# Epoch 2716/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8057 - accuracy: 0.6291 - val_loss: 1.5852 - val_accuracy: 0.3723
# Epoch 2717/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8018 - accuracy: 0.6495 - val_loss: 1.5954 - val_accuracy: 0.3723
# Epoch 2718/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8282 - accuracy: 0.6225 - val_loss: 1.5957 - val_accuracy: 0.3686
# Epoch 2719/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8047 - accuracy: 0.6458 - val_loss: 1.5962 - val_accuracy: 0.3577
# Epoch 2720/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8110 - accuracy: 0.6313 - val_loss: 1.5918 - val_accuracy: 0.3759
# Epoch 2721/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8208 - accuracy: 0.6189 - val_loss: 1.5825 - val_accuracy: 0.3832
# Epoch 2722/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8281 - accuracy: 0.6240 - val_loss: 1.5860 - val_accuracy: 0.3613
# Epoch 2723/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8218 - accuracy: 0.6255 - val_loss: 1.5934 - val_accuracy: 0.3650
# Epoch 2724/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8319 - accuracy: 0.6153 - val_loss: 1.6006 - val_accuracy: 0.3723
# Epoch 2725/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8254 - accuracy: 0.6211 - val_loss: 1.5935 - val_accuracy: 0.3613
# Epoch 2726/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8378 - accuracy: 0.6284 - val_loss: 1.5914 - val_accuracy: 0.3723
# Epoch 2727/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8279 - accuracy: 0.6240 - val_loss: 1.5881 - val_accuracy: 0.3650
# Epoch 2728/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8180 - accuracy: 0.6291 - val_loss: 1.5968 - val_accuracy: 0.3796
# Epoch 2729/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8145 - accuracy: 0.6385 - val_loss: 1.5895 - val_accuracy: 0.3577
# Epoch 2730/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8370 - accuracy: 0.6233 - val_loss: 1.6001 - val_accuracy: 0.3759
# Epoch 2731/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8272 - accuracy: 0.6269 - val_loss: 1.5880 - val_accuracy: 0.3723
# Epoch 2732/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8443 - accuracy: 0.6102 - val_loss: 1.5785 - val_accuracy: 0.3686
# Epoch 2733/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8301 - accuracy: 0.6211 - val_loss: 1.5916 - val_accuracy: 0.3796
# Epoch 2734/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8212 - accuracy: 0.6087 - val_loss: 1.5933 - val_accuracy: 0.3723
# Epoch 2735/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8341 - accuracy: 0.6138 - val_loss: 1.5849 - val_accuracy: 0.3832
# Epoch 2736/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8049 - accuracy: 0.6364 - val_loss: 1.5858 - val_accuracy: 0.3650
# Epoch 2737/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8360 - accuracy: 0.6204 - val_loss: 1.5937 - val_accuracy: 0.3796
# Epoch 2738/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8393 - accuracy: 0.6313 - val_loss: 1.5853 - val_accuracy: 0.3796
# Epoch 2739/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8201 - accuracy: 0.6255 - val_loss: 1.5862 - val_accuracy: 0.3759
# Epoch 2740/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8463 - accuracy: 0.6022 - val_loss: 1.5900 - val_accuracy: 0.3796
# Epoch 2741/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8159 - accuracy: 0.6356 - val_loss: 1.5845 - val_accuracy: 0.3723
# Epoch 2742/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8167 - accuracy: 0.6327 - val_loss: 1.5803 - val_accuracy: 0.3723
# Epoch 2743/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8146 - accuracy: 0.6276 - val_loss: 1.5777 - val_accuracy: 0.3650
# Epoch 2744/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8281 - accuracy: 0.6138 - val_loss: 1.5912 - val_accuracy: 0.3759
# Epoch 2745/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8287 - accuracy: 0.6211 - val_loss: 1.5856 - val_accuracy: 0.3796
# Epoch 2746/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8237 - accuracy: 0.6313 - val_loss: 1.5802 - val_accuracy: 0.3686
# Epoch 2747/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8401 - accuracy: 0.6196 - val_loss: 1.5895 - val_accuracy: 0.3759
# Epoch 2748/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8413 - accuracy: 0.6058 - val_loss: 1.5786 - val_accuracy: 0.3723
# Epoch 2749/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8222 - accuracy: 0.6196 - val_loss: 1.5753 - val_accuracy: 0.3723
# Epoch 2750/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8569 - accuracy: 0.6182 - val_loss: 1.5739 - val_accuracy: 0.3723
# Epoch 2751/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8343 - accuracy: 0.6196 - val_loss: 1.5953 - val_accuracy: 0.3796
# Epoch 2752/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8082 - accuracy: 0.6400 - val_loss: 1.5911 - val_accuracy: 0.3759
# Epoch 2753/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8150 - accuracy: 0.6335 - val_loss: 1.5920 - val_accuracy: 0.3796
# Epoch 2754/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8159 - accuracy: 0.6495 - val_loss: 1.5770 - val_accuracy: 0.3832
# Epoch 2755/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8219 - accuracy: 0.6182 - val_loss: 1.5858 - val_accuracy: 0.3832
# Epoch 2756/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8256 - accuracy: 0.6225 - val_loss: 1.5800 - val_accuracy: 0.3686
# Epoch 2757/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8036 - accuracy: 0.6400 - val_loss: 1.5937 - val_accuracy: 0.3723
# Epoch 2758/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8248 - accuracy: 0.6364 - val_loss: 1.5797 - val_accuracy: 0.3796
# Epoch 2759/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8149 - accuracy: 0.6335 - val_loss: 1.5695 - val_accuracy: 0.3832
# Epoch 2760/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8184 - accuracy: 0.6211 - val_loss: 1.5719 - val_accuracy: 0.3759
# Epoch 2761/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8076 - accuracy: 0.6327 - val_loss: 1.5693 - val_accuracy: 0.3796
# Epoch 2762/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8232 - accuracy: 0.6218 - val_loss: 1.5851 - val_accuracy: 0.3686
# Epoch 2763/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8188 - accuracy: 0.6335 - val_loss: 1.5779 - val_accuracy: 0.3723
# Epoch 2764/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7980 - accuracy: 0.6436 - val_loss: 1.5838 - val_accuracy: 0.3650
# Epoch 2765/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8259 - accuracy: 0.6335 - val_loss: 1.5887 - val_accuracy: 0.3832
# Epoch 2766/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8205 - accuracy: 0.6116 - val_loss: 1.5884 - val_accuracy: 0.3759
# Epoch 2767/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8368 - accuracy: 0.6109 - val_loss: 1.6002 - val_accuracy: 0.3723
# Epoch 2768/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8378 - accuracy: 0.6320 - val_loss: 1.5937 - val_accuracy: 0.3759
# Epoch 2769/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8190 - accuracy: 0.6204 - val_loss: 1.5773 - val_accuracy: 0.3832
# Epoch 2770/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8171 - accuracy: 0.6109 - val_loss: 1.5863 - val_accuracy: 0.3832
# Epoch 2771/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8118 - accuracy: 0.6335 - val_loss: 1.5760 - val_accuracy: 0.3796
# Epoch 2772/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8104 - accuracy: 0.6196 - val_loss: 1.5762 - val_accuracy: 0.3650
# Epoch 2773/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8134 - accuracy: 0.6269 - val_loss: 1.5770 - val_accuracy: 0.3832
# Epoch 2774/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8109 - accuracy: 0.6335 - val_loss: 1.6022 - val_accuracy: 0.3686
# Epoch 2775/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8220 - accuracy: 0.6218 - val_loss: 1.6001 - val_accuracy: 0.3686
# Epoch 2776/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8157 - accuracy: 0.6342 - val_loss: 1.5933 - val_accuracy: 0.3650
# Epoch 2777/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8265 - accuracy: 0.6247 - val_loss: 1.5806 - val_accuracy: 0.3796
# Epoch 2778/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8238 - accuracy: 0.6218 - val_loss: 1.5768 - val_accuracy: 0.3796
# Epoch 2779/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8198 - accuracy: 0.6189 - val_loss: 1.5894 - val_accuracy: 0.3686
# Epoch 2780/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8354 - accuracy: 0.6284 - val_loss: 1.5901 - val_accuracy: 0.3796
# Epoch 2781/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8344 - accuracy: 0.6313 - val_loss: 1.5946 - val_accuracy: 0.3759
# Epoch 2782/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8414 - accuracy: 0.6204 - val_loss: 1.5849 - val_accuracy: 0.3759
# Epoch 2783/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8409 - accuracy: 0.6233 - val_loss: 1.5824 - val_accuracy: 0.3796
# Epoch 2784/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8249 - accuracy: 0.6116 - val_loss: 1.5698 - val_accuracy: 0.3832
# Epoch 2785/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8231 - accuracy: 0.6305 - val_loss: 1.5734 - val_accuracy: 0.3759
# Epoch 2786/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8241 - accuracy: 0.6225 - val_loss: 1.5691 - val_accuracy: 0.3723
# Epoch 2787/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8194 - accuracy: 0.6349 - val_loss: 1.5866 - val_accuracy: 0.3759
# Epoch 2788/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8392 - accuracy: 0.6116 - val_loss: 1.5843 - val_accuracy: 0.3650
# Epoch 2789/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8189 - accuracy: 0.6356 - val_loss: 1.5802 - val_accuracy: 0.3796
# Epoch 2790/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8223 - accuracy: 0.6175 - val_loss: 1.5861 - val_accuracy: 0.3759
# Epoch 2791/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8167 - accuracy: 0.6298 - val_loss: 1.5900 - val_accuracy: 0.3686
# Epoch 2792/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8148 - accuracy: 0.6429 - val_loss: 1.5709 - val_accuracy: 0.3832
# Epoch 2793/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8334 - accuracy: 0.6335 - val_loss: 1.5865 - val_accuracy: 0.3869
# Epoch 2794/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8140 - accuracy: 0.6189 - val_loss: 1.5955 - val_accuracy: 0.3869
# Epoch 2795/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8190 - accuracy: 0.6276 - val_loss: 1.5918 - val_accuracy: 0.3832
# Epoch 2796/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8280 - accuracy: 0.6138 - val_loss: 1.5824 - val_accuracy: 0.3905
# Epoch 2797/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8212 - accuracy: 0.6393 - val_loss: 1.5889 - val_accuracy: 0.3796
# Epoch 2798/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8316 - accuracy: 0.6131 - val_loss: 1.6010 - val_accuracy: 0.3650
# Epoch 2799/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8383 - accuracy: 0.6269 - val_loss: 1.5908 - val_accuracy: 0.3796
# Epoch 2800/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8209 - accuracy: 0.6225 - val_loss: 1.5935 - val_accuracy: 0.3723
# Epoch 2801/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8016 - accuracy: 0.6393 - val_loss: 1.5990 - val_accuracy: 0.3723
# Epoch 2802/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8134 - accuracy: 0.6276 - val_loss: 1.6007 - val_accuracy: 0.3759
# Epoch 2803/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8062 - accuracy: 0.6335 - val_loss: 1.5814 - val_accuracy: 0.3650
# Epoch 2804/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8123 - accuracy: 0.6175 - val_loss: 1.5710 - val_accuracy: 0.3796
# Epoch 2805/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8274 - accuracy: 0.6269 - val_loss: 1.5893 - val_accuracy: 0.3759
# Epoch 2806/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8362 - accuracy: 0.6109 - val_loss: 1.5908 - val_accuracy: 0.3686
# Epoch 2807/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8150 - accuracy: 0.6255 - val_loss: 1.5742 - val_accuracy: 0.3650
# Epoch 2808/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8085 - accuracy: 0.6385 - val_loss: 1.5835 - val_accuracy: 0.3650
# Epoch 2809/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8055 - accuracy: 0.6225 - val_loss: 1.5845 - val_accuracy: 0.3796
# Epoch 2810/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8328 - accuracy: 0.6109 - val_loss: 1.5844 - val_accuracy: 0.3759
# Epoch 2811/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8112 - accuracy: 0.6225 - val_loss: 1.5788 - val_accuracy: 0.3796
# Epoch 2812/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8139 - accuracy: 0.6451 - val_loss: 1.5707 - val_accuracy: 0.3832
# Epoch 2813/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8235 - accuracy: 0.6284 - val_loss: 1.5869 - val_accuracy: 0.3796
# Epoch 2814/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8035 - accuracy: 0.6393 - val_loss: 1.5775 - val_accuracy: 0.3832
# Epoch 2815/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8137 - accuracy: 0.6538 - val_loss: 1.5859 - val_accuracy: 0.3796
# Epoch 2816/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8281 - accuracy: 0.6175 - val_loss: 1.5806 - val_accuracy: 0.3832
# Epoch 2817/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8236 - accuracy: 0.6262 - val_loss: 1.5840 - val_accuracy: 0.3869
# Epoch 2818/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8332 - accuracy: 0.6109 - val_loss: 1.5859 - val_accuracy: 0.3796
# Epoch 2819/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8336 - accuracy: 0.6211 - val_loss: 1.5776 - val_accuracy: 0.3796
# Epoch 2820/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8118 - accuracy: 0.6313 - val_loss: 1.5975 - val_accuracy: 0.3796
# Epoch 2821/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8366 - accuracy: 0.6262 - val_loss: 1.5886 - val_accuracy: 0.3832
# Epoch 2822/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8351 - accuracy: 0.6051 - val_loss: 1.5816 - val_accuracy: 0.3832
# Epoch 2823/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8176 - accuracy: 0.6240 - val_loss: 1.5886 - val_accuracy: 0.3869
# Epoch 2824/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8252 - accuracy: 0.6116 - val_loss: 1.5933 - val_accuracy: 0.3832
# Epoch 2825/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8024 - accuracy: 0.6349 - val_loss: 1.6066 - val_accuracy: 0.3796
# Epoch 2826/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8340 - accuracy: 0.6233 - val_loss: 1.5974 - val_accuracy: 0.3796
# Epoch 2827/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8105 - accuracy: 0.6320 - val_loss: 1.5923 - val_accuracy: 0.3832
# Epoch 2828/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8018 - accuracy: 0.6276 - val_loss: 1.5850 - val_accuracy: 0.3869
# Epoch 2829/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8401 - accuracy: 0.6233 - val_loss: 1.5834 - val_accuracy: 0.3796
# Epoch 2830/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8284 - accuracy: 0.6145 - val_loss: 1.5992 - val_accuracy: 0.3832
# Epoch 2831/5000
# ...
# Epoch 4891/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7948 - accuracy: 0.6349 - val_loss: 1.6587 - val_accuracy: 0.3650
# Epoch 4892/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8009 - accuracy: 0.6255 - val_loss: 1.6694 - val_accuracy: 0.3759
# Epoch 4893/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7959 - accuracy: 0.6378 - val_loss: 1.6883 - val_accuracy: 0.3723
# Epoch 4894/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7951 - accuracy: 0.6393 - val_loss: 1.6687 - val_accuracy: 0.3723
# Epoch 4895/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7791 - accuracy: 0.6480 - val_loss: 1.6570 - val_accuracy: 0.3686
# Epoch 4896/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7850 - accuracy: 0.6342 - val_loss: 1.6636 - val_accuracy: 0.3686
# Epoch 4897/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7992 - accuracy: 0.6407 - val_loss: 1.6756 - val_accuracy: 0.3759
# Epoch 4898/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7831 - accuracy: 0.6284 - val_loss: 1.6808 - val_accuracy: 0.3723
# Epoch 4899/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8250 - accuracy: 0.6116 - val_loss: 1.6616 - val_accuracy: 0.3759
# Epoch 4900/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7839 - accuracy: 0.6640 - val_loss: 1.6750 - val_accuracy: 0.3832
# Epoch 4901/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7766 - accuracy: 0.6516 - val_loss: 1.6774 - val_accuracy: 0.3832
# Epoch 4902/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7918 - accuracy: 0.6451 - val_loss: 1.6708 - val_accuracy: 0.3759
# Epoch 4903/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7901 - accuracy: 0.6429 - val_loss: 1.6559 - val_accuracy: 0.3686
# Epoch 4904/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7952 - accuracy: 0.6400 - val_loss: 1.6656 - val_accuracy: 0.3759
# Epoch 4905/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8000 - accuracy: 0.6298 - val_loss: 1.6495 - val_accuracy: 0.3832
# Epoch 4906/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7806 - accuracy: 0.6393 - val_loss: 1.6639 - val_accuracy: 0.3723
# Epoch 4907/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8156 - accuracy: 0.6320 - val_loss: 1.6613 - val_accuracy: 0.3723
# Epoch 4908/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.7886 - accuracy: 0.6458 - val_loss: 1.6649 - val_accuracy: 0.3796
# Epoch 4909/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7972 - accuracy: 0.6371 - val_loss: 1.6684 - val_accuracy: 0.3759
# Epoch 4910/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7945 - accuracy: 0.6407 - val_loss: 1.6765 - val_accuracy: 0.3796
# Epoch 4911/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7937 - accuracy: 0.6516 - val_loss: 1.6721 - val_accuracy: 0.3650
# Epoch 4912/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7876 - accuracy: 0.6407 - val_loss: 1.6644 - val_accuracy: 0.3723
# Epoch 4913/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7926 - accuracy: 0.6553 - val_loss: 1.6724 - val_accuracy: 0.3723
# Epoch 4914/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8080 - accuracy: 0.6429 - val_loss: 1.6815 - val_accuracy: 0.3759
# Epoch 4915/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.7787 - accuracy: 0.6451 - val_loss: 1.6830 - val_accuracy: 0.3686
# Epoch 4916/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8078 - accuracy: 0.6247 - val_loss: 1.6755 - val_accuracy: 0.3723
# Epoch 4917/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7933 - accuracy: 0.6415 - val_loss: 1.6830 - val_accuracy: 0.3723
# Epoch 4918/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7755 - accuracy: 0.6596 - val_loss: 1.6694 - val_accuracy: 0.3686
# Epoch 4919/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7850 - accuracy: 0.6582 - val_loss: 1.6814 - val_accuracy: 0.3686
# Epoch 4920/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8020 - accuracy: 0.6451 - val_loss: 1.6840 - val_accuracy: 0.3723
# Epoch 4921/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7951 - accuracy: 0.6422 - val_loss: 1.6937 - val_accuracy: 0.3723
# Epoch 4922/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7984 - accuracy: 0.6458 - val_loss: 1.6856 - val_accuracy: 0.3723
# Epoch 4923/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7790 - accuracy: 0.6444 - val_loss: 1.6783 - val_accuracy: 0.3723
# Epoch 4924/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7901 - accuracy: 0.6502 - val_loss: 1.6731 - val_accuracy: 0.3796
# Epoch 4925/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7986 - accuracy: 0.6385 - val_loss: 1.6717 - val_accuracy: 0.3796
# Epoch 4926/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7918 - accuracy: 0.6487 - val_loss: 1.6801 - val_accuracy: 0.3650
# Epoch 4927/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8081 - accuracy: 0.6175 - val_loss: 1.6625 - val_accuracy: 0.3650
# Epoch 4928/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7829 - accuracy: 0.6465 - val_loss: 1.6711 - val_accuracy: 0.3686
# Epoch 4929/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7994 - accuracy: 0.6262 - val_loss: 1.6690 - val_accuracy: 0.3723
# Epoch 4930/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8011 - accuracy: 0.6364 - val_loss: 1.6697 - val_accuracy: 0.3723
# Epoch 4931/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8099 - accuracy: 0.6342 - val_loss: 1.6607 - val_accuracy: 0.3723
# Epoch 4932/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8098 - accuracy: 0.6349 - val_loss: 1.6709 - val_accuracy: 0.3650
# Epoch 4933/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7780 - accuracy: 0.6604 - val_loss: 1.6734 - val_accuracy: 0.3723
# Epoch 4934/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7951 - accuracy: 0.6364 - val_loss: 1.6822 - val_accuracy: 0.3723
# Epoch 4935/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7856 - accuracy: 0.6582 - val_loss: 1.6756 - val_accuracy: 0.3686
# Epoch 4936/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7821 - accuracy: 0.6444 - val_loss: 1.6750 - val_accuracy: 0.3723
# Epoch 4937/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7821 - accuracy: 0.6516 - val_loss: 1.6773 - val_accuracy: 0.3686
# Epoch 4938/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7899 - accuracy: 0.6313 - val_loss: 1.6852 - val_accuracy: 0.3723
# Epoch 4939/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7971 - accuracy: 0.6400 - val_loss: 1.6736 - val_accuracy: 0.3723
# Epoch 4940/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7944 - accuracy: 0.6284 - val_loss: 1.6763 - val_accuracy: 0.3650
# Epoch 4941/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8063 - accuracy: 0.6291 - val_loss: 1.6792 - val_accuracy: 0.3723
# Epoch 4942/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8174 - accuracy: 0.6320 - val_loss: 1.6727 - val_accuracy: 0.3686
# Epoch 4943/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8033 - accuracy: 0.6393 - val_loss: 1.6674 - val_accuracy: 0.3759
# Epoch 4944/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8048 - accuracy: 0.6436 - val_loss: 1.6585 - val_accuracy: 0.3613
# Epoch 4945/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7836 - accuracy: 0.6516 - val_loss: 1.6646 - val_accuracy: 0.3686
# Epoch 4946/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8084 - accuracy: 0.6211 - val_loss: 1.6612 - val_accuracy: 0.3723
# Epoch 4947/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8111 - accuracy: 0.6371 - val_loss: 1.6627 - val_accuracy: 0.3686
# Epoch 4948/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8076 - accuracy: 0.6378 - val_loss: 1.6600 - val_accuracy: 0.3686
# Epoch 4949/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8070 - accuracy: 0.6356 - val_loss: 1.6784 - val_accuracy: 0.3796
# Epoch 4950/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7805 - accuracy: 0.6545 - val_loss: 1.6641 - val_accuracy: 0.3686
# Epoch 4951/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7848 - accuracy: 0.6335 - val_loss: 1.6683 - val_accuracy: 0.3686
# Epoch 4952/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7907 - accuracy: 0.6349 - val_loss: 1.6633 - val_accuracy: 0.3796
# Epoch 4953/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7894 - accuracy: 0.6495 - val_loss: 1.6578 - val_accuracy: 0.3723
# Epoch 4954/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7919 - accuracy: 0.6305 - val_loss: 1.6685 - val_accuracy: 0.3796
# Epoch 4955/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8085 - accuracy: 0.6531 - val_loss: 1.6462 - val_accuracy: 0.3796
# Epoch 4956/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7785 - accuracy: 0.6611 - val_loss: 1.6572 - val_accuracy: 0.3796
# Epoch 4957/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7833 - accuracy: 0.6473 - val_loss: 1.6609 - val_accuracy: 0.3686
# Epoch 4958/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8026 - accuracy: 0.6262 - val_loss: 1.6556 - val_accuracy: 0.3723
# Epoch 4959/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8095 - accuracy: 0.6371 - val_loss: 1.6554 - val_accuracy: 0.3723
# Epoch 4960/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8070 - accuracy: 0.6313 - val_loss: 1.6655 - val_accuracy: 0.3832
# Epoch 4961/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7808 - accuracy: 0.6429 - val_loss: 1.6628 - val_accuracy: 0.3759
# Epoch 4962/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7921 - accuracy: 0.6589 - val_loss: 1.6497 - val_accuracy: 0.3759
# Epoch 4963/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7742 - accuracy: 0.6524 - val_loss: 1.6574 - val_accuracy: 0.3796
# Epoch 4964/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.7903 - accuracy: 0.6516 - val_loss: 1.6724 - val_accuracy: 0.3723
# Epoch 4965/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8068 - accuracy: 0.6262 - val_loss: 1.6634 - val_accuracy: 0.3796
# Epoch 4966/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8082 - accuracy: 0.6429 - val_loss: 1.6669 - val_accuracy: 0.3686
# Epoch 4967/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8077 - accuracy: 0.6255 - val_loss: 1.6731 - val_accuracy: 0.3650
# Epoch 4968/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7889 - accuracy: 0.6444 - val_loss: 1.6748 - val_accuracy: 0.3723
# Epoch 4969/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7806 - accuracy: 0.6516 - val_loss: 1.6686 - val_accuracy: 0.3759
# Epoch 4970/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8002 - accuracy: 0.6364 - val_loss: 1.6667 - val_accuracy: 0.3686
# Epoch 4971/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7739 - accuracy: 0.6538 - val_loss: 1.6653 - val_accuracy: 0.3723
# Epoch 4972/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7829 - accuracy: 0.6465 - val_loss: 1.6775 - val_accuracy: 0.3686
# Epoch 4973/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7956 - accuracy: 0.6291 - val_loss: 1.6568 - val_accuracy: 0.3796
# Epoch 4974/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8143 - accuracy: 0.6225 - val_loss: 1.6681 - val_accuracy: 0.3723
# Epoch 4975/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7924 - accuracy: 0.6255 - val_loss: 1.6804 - val_accuracy: 0.3723
# Epoch 4976/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7991 - accuracy: 0.6320 - val_loss: 1.6612 - val_accuracy: 0.3869
# Epoch 4977/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7894 - accuracy: 0.6495 - val_loss: 1.6561 - val_accuracy: 0.3832
# Epoch 4978/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.7934 - accuracy: 0.6495 - val_loss: 1.6615 - val_accuracy: 0.3796
# Epoch 4979/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7837 - accuracy: 0.6458 - val_loss: 1.6615 - val_accuracy: 0.3832
# Epoch 4980/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7917 - accuracy: 0.6516 - val_loss: 1.6594 - val_accuracy: 0.3723
# Epoch 4981/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7885 - accuracy: 0.6385 - val_loss: 1.6711 - val_accuracy: 0.3869
# Epoch 4982/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7791 - accuracy: 0.6640 - val_loss: 1.6806 - val_accuracy: 0.3832
# Epoch 4983/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7989 - accuracy: 0.6378 - val_loss: 1.6672 - val_accuracy: 0.3832
# Epoch 4984/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.7948 - accuracy: 0.6247 - val_loss: 1.6540 - val_accuracy: 0.3905
# Epoch 4985/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.7928 - accuracy: 0.6335 - val_loss: 1.6654 - val_accuracy: 0.3832
# Epoch 4986/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8106 - accuracy: 0.6196 - val_loss: 1.6697 - val_accuracy: 0.3869
# Epoch 4987/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7969 - accuracy: 0.6276 - val_loss: 1.6506 - val_accuracy: 0.3759
# Epoch 4988/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8022 - accuracy: 0.6262 - val_loss: 1.6708 - val_accuracy: 0.3832
# Epoch 4989/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7822 - accuracy: 0.6356 - val_loss: 1.6474 - val_accuracy: 0.3796
# Epoch 4990/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8032 - accuracy: 0.6211 - val_loss: 1.6377 - val_accuracy: 0.3832
# Epoch 4991/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7848 - accuracy: 0.6393 - val_loss: 1.6643 - val_accuracy: 0.3869
# Epoch 4992/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7867 - accuracy: 0.6429 - val_loss: 1.6574 - val_accuracy: 0.3869
# Epoch 4993/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8048 - accuracy: 0.6422 - val_loss: 1.6765 - val_accuracy: 0.3869
# Epoch 4994/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.8146 - accuracy: 0.6349 - val_loss: 1.6759 - val_accuracy: 0.3869
# Epoch 4995/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7641 - accuracy: 0.6778 - val_loss: 1.6574 - val_accuracy: 0.3869
# Epoch 4996/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7907 - accuracy: 0.6335 - val_loss: 1.6689 - val_accuracy: 0.3796
# Epoch 4997/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7931 - accuracy: 0.6444 - val_loss: 1.6581 - val_accuracy: 0.3759
# Epoch 4998/5000
# 43/43 [==============================] - 0s 3ms/step - loss: 0.7903 - accuracy: 0.6495 - val_loss: 1.6680 - val_accuracy: 0.3869
# Epoch 4999/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.7847 - accuracy: 0.6415 - val_loss: 1.6629 - val_accuracy: 0.3869
# Epoch 5000/5000
# 43/43 [==============================] - 0s 4ms/step - loss: 0.8020 - accuracy: 0.6458 - val_loss: 1.6726 - val_accuracy: 0.3869

# %% [markdown]
# # Classifier Device Images

# %%
# !ls data
# Out:
# exp13_ctl_sep2		Pig_Labels_Cleaned_FINALESTFINALLLL.csv
# exp_ctl_sep2_test.npy	Pig_Labels_Cleaned_FINALESTFINALLLL.gsheet
# exp_ctl_sep2_train.npy	Sep2_cleaned_control_images
# iphone_train		test_ctl_sep2_3x4_quad
# iphone_val		train_ctl_sep2
# near			train_ctl_sep2_3x4_quad
# patch_healnet_arrays

# %%
#Load images (cleaned, no pairs)
imgs_train = glob.glob('/content/drive/MyDrive/BETR_Summer23/data/Sep2_cleaned_control_images_Patch_Image/train_ctl_sep2_3x4_quad/*.jpg', recursive = True)
imgs_val = glob.glob('/content/drive/MyDrive/BETR_Summer23/data/Sep2_cleaned_control_images_Patch_Image/test_ctl_sep2_3x4_quad/*.jpg', recursive = True)
print(len(imgs_train), len(imgs_val))
# Out:
# 39255 8087

# %%
# Out:
# test_ctl_sep2_3x4_quad	train_ctl_sep2_3x4_quad

# %%
day_to_stage = {"0": 0, "1":1, "2":1, "3":2, "4":2, "5":2, "6":2}
# 0-value is hemostastis
# 1-value is inflam
# 2-value is prol
# 3-value would be maturation

#add labels train
labels_train = []
for x in imgs_train:
    tmp = x.split("/")[-1].split("_")[5]
    labels_train.append(day_to_stage[tmp])

labels_val = []
for x in imgs_val:
    tmp = x.split("/")[-1].split("_")[5]
    labels_val.append(day_to_stage[tmp])

# %%
train_df = pd.DataFrame(imgs_train, columns = ["image"])
train_df['cluster']=labels_train

val_df = pd.DataFrame(imgs_val, columns = ["image"])
val_df['cluster']=labels_val

img_dir = None
 # not doing any rescaling here as preprocess_input should deal with it
image_generator = ImageDataGenerator(

)
train_generator = image_generator.flow_from_dataframe(
    dataframe = train_df,
    #directory = img_dir,
    x_col = "image",
    y_col = "cluster",
    batch_size = 1024,
    shuffle = True,
    class_mode = "raw",
    target_size = (128, 128)
)

# Flow from directory with specified batch size and target image size
val_generator = image_generator.flow_from_dataframe(
    dataframe = val_df,
    #directory = img_dir,
    x_col = "image", # features
    y_col = "cluster", # labels
    class_mode = "raw", # 'Mass' column should be in train_df
    batch_size = 1024, # images per batch
    shuffle = False, # shuffle the rows or not
    target_size = (128, 128) # width and height of output image
)
print(len(train_generator), len(val_generator))
# Out:
# Found 39255 validated image filenames.
# Found 8087 validated image filenames.
# 39 8

# %%
#dense_cls = keras.models.load_model("Saved Weights/Patch_HealNet_k4_corrected.h5")

# %%
#base_model = keras.models.load_model("Saved Weights/HealNet_base_model_full_device_test=13_sep2.h5")

# %%
in_shape = (128, 128, 3)
latent_size = 16

# %%
#Initiate classifier models


# change this for output head PLEASE
base_model2 = DenseNet121(
     weights='imagenet',
     include_top=False,
     input_shape=in_shape)

# This actually happens second than below
x = base_model.output
x = GlobalMaxPooling2D()(x) # should we do average pooling?
x = Dropout(0.5)(x) # should experiment with this
x = Dense(latent_size)(x)

feature_extractor = Model(inputs=base_model.input, outputs=x)

feature_extractor.load_weights( './Saved Weights/temporal_encoder_Michael_Nov5_GaussianBlur.h5' ) # Feature extractor is the "image encoder"
feature_extractor.trainable = False

feature_extractor.layers[-1].trainable = True

input = Input(shape=in_shape)
CLASSES = 3
x = RandomFlip("horizontal_and_vertical")(input)
x = RandomRotation(0.5, fill_mode='constant')(x)
x = RandomContrast(0.5)(x)

x = densenet_preprocess(x)

#x = base_model(x) # same model weights as before
x = feature_extractor(x)

# Need to find a way to combine all the 16-dim latents

x = Dense(16, activation="relu")(x)
x = Dense(16, activation="relu")(x)
x = Dense(CLASSES, activation="softmax")(x)

dense_cls = Model(inputs=input, outputs=x)

# %%
# !ls 'Saved Weights'

# %%
# Load classifier weights
#dense_cls = keras.models.load_model('Saved Weights/HealNet_device_exp13_day3=pro_resnet_sep2_v1_2500+.h5')

# %%
dense_cls.compile(loss='sparse_categorical_crossentropy',
                  optimizer=Adam(0.0075), # small learning rate since we're transfer learning
                  metrics=['accuracy'])

# %%
best_model_file = "./Saved Weights/HealNet_device_nov_5.h5"

earlystop = EarlyStopping(monitor = 'val_accuracy',
                          min_delta = 0,
                          patience = 1000,
                          verbose = 1,
                          restore_best_weights = True)

reduce_lr = ReduceLROnPlateau(monitor='val_accuracy',
                              factor = 0.5,
                              patience = 200,
                              min_lr = 0.0000001,
                              verbose = 1)

tensor_board = tbCallBack = TensorBoard(log_dir = './logs/Patch_HealNet_device_exp12_no_val',
                                        histogram_freq = 0,
                                        write_graph = True,
                                        write_images = False)

best_model = ModelCheckpoint(best_model_file,
                             monitor = 'val_accuracy',
                             mode = 'auto',
                             verbose = 0,
                             save_best_only = True)

callback_list = [reduce_lr, earlystop, best_model, tensor_board]

# %%
dense_cls_history_ft = dense_cls.fit(
    train_generator,
    validation_data = val_generator,
    epochs = 2500,
    verbose = 1,
    callbacks = callback_list)

#print( len(train_imgs), len(val_imgs), len(labels_train), len(labels_val) )
#history_densenet = dense_cls.fit(
#    x = train_imgs,
#    y = labels_train,
#    validation_data = (val_imgs, labels_val),
#    batch_size = 128,
#    epochs = 2500,
#    verbose = 1,
#    callbacks = callback_list
#)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-2b8db22ad473> in <cell line: 1>()
# ----> 1 dense_cls_history_ft = dense_cls.fit(
#       2     train_generator,
#       3     validation_data = val_generator,
#       4     epochs = 2500,
#       5     verbose = 1,
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1499         ):
#    1500             # Creates a `tf.data.Dataset` and handles batch and epoch iteration.
# -> 1501             data_handler = data_adapter.get_data_handler(
#    1502                 x=x,
#    1503                 y=y,
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py in get_data_handler(*args, **kwargs)
#    1580     if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1581         return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1582     return DataHandler(*args, **kwargs)
#    1583
#    1584
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1260
#    1261         adapter_cls = select_data_adapter(x, y)
# -> 1262         self._adapter = adapter_cls(
#    1263             x,
#    1264             y,
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, shuffle, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#    1008         self._keras_sequence = x
#    1009         self._enqueuer = None
# -> 1010         super().__init__(
#    1011             x,
#    1012             shuffle=False,  # Shuffle is handed in the _make_callable override.
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py in __init__(self, x, y, sample_weights, workers, use_multiprocessing, max_queue_size, model, **kwargs)
#     867         # Since we have to know the dtype of the python generator when we build
#     868         # the dataset, we have to look at a batch to infer the structure.
# --> 869         peek, x = self._peek_and_restore(x)
#     870         peek = self._standardize_batch(peek)
#     871         peek = _process_tensorlike(peek)
#
# /usr/local/lib/python3.10/dist-packages/keras/engine/data_adapter.py in _peek_and_restore(x)
#    1020     @staticmethod
#    1021     def _peek_and_restore(x):
# -> 1022         return x[0], x
#    1023
#    1024     def _handle_multiprocessing(
#
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py in __getitem__(self, idx)
#     114             self.batch_size * idx : self.batch_size * (idx + 1)
#     115         ]
# --> 116         return self._get_batches_of_transformed_samples(index_array)
#     117
#     118     def __len__(self):
#
# /usr/local/lib/python3.10/dist-packages/keras/preprocessing/image.py in _get_batches_of_transformed_samples(self, index_array)
#     368         filepaths = self.filepaths
#     369         for i, j in enumerate(index_array):
# --> 370             img = image_utils.load_img(
#     371                 filepaths[j],
#     372                 color_mode=self.color_mode,
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/image_utils.py in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     421             path = str(path.resolve())
#     422         with open(path, "rb") as f:
# --> 423             img = pil_image.open(io.BytesIO(f.read()))
#     424     else:
#     425         raise TypeError(
#
# KeyboardInterrupt:

# %%
val_acc = history_densenet.history['val_accuracy'][:]
acc = history_densenet.history['accuracy']

plt.plot(acc, label='Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend()
plt.ylabel('Accuracy (%)')
plt.title('Temporal Training DenseNet Accuracy')
plt.xlabel('Epoch')
plt.savefig('Temporal Encoder DenseNet (Blanced Patch) Accuracy.pdf')
plt.show()

# %%
val_acc = history_densenet.history['val_loss'][:]
acc = history_densenet.history['loss']

plt.plot(acc, label='Loss')
plt.plot(val_acc, label='Validation Loss')
plt.legend()
plt.ylabel('Loss')
plt.title('Temporal Training DenseNet Loss')
plt.xlabel('Epoch')
plt.savefig('Temporal Encoder DenseNet (Blanced Patch) Loss.pdf')
plt.show()

# %%
test_loss, test_acc = dense_cls.evaluate(x=val_imgs, y=labels_val)
# Out:
# 69/69 [==============================] - 4s 33ms/step - loss: 0.4218 - accuracy: 0.8547

# %%
test_loss, test_acc = dense_cls.evaluate(x=train_imgs, y=labels_train)
# Out:
# 24/24 [==============================] - 1s 35ms/step - loss: 0.4537 - accuracy: 0.8105

# %%
# This disiplays the image by wound/xp by day
# pd.crosstab(index=data['wound'], columns=data['day'], margins=True)
# Out:
# day      0    1    2    3    4    5    6   All
# wound
# 103     32   66    0    0    0    0    0    98
# 107     41   96   69   40   59   65    0   370
# 113     49   50   55   31   33   22   16   256
# 117     63   55   55   38   39   10   11   271
# 123     23   44   48   55   60   55   60   345
# 127     40   60   45   30   54  108  162   499
# 131     23    0    0    0    0    0    0    23
# 132      0    1    0    0    0    2    0     3
# 135      0   11   14   60  110   15   10   220
# 136     13   17   39   54   78   14   48   263
# 83      43    0   75   32   45    0    0   195
# 87      38    0    0   83  120  132   52   425
# All    365  400  400  423  598  423  359  2968

# %% [markdown]
# # Patch Classifier for Device Images

# %%
day_to_stage = {"0": 0, "1":1, "2":1, "3":2, "4":2, "5":2, "6":2} # Day to wound stage Dictionary

# %%
# This was a the task for an undergrad

# %% [markdown]
# # MIL shuffle & learn dataset

# %%
# Read in the images
base_train =  'MIL/data/abMIL_12_Train/'
imgs_train = glob.glob(base_train+'*.jpg')
len(imgs_train)
# Out:
# 36408

# %% [markdown]
# ## Create image list

# %%
"""

import shutil
# fix wounds with 1_5, 2_6 as wounds 15 and 26
#tmp_arr = []
count = 0
for x in imgs_train:
    if len(x.split("/")[-1].split("_")) >= 10:
        tmp = x.split("/")
        tmp1 = tmp[-1].split("_")

        tmp1[3]=tmp1[3]+tmp1[4]
        del tmp1[4]

#imgs_train = tmp_arr
print(count)
"""

# %%
"""
import shutil
# remove unlocatable wounds
tmp_arr = []
for x in imgs_train:
    if "Photos by Device" in x:
        tmp = x.split("/")
        #print(tmp)
        #break
        #tmp1 = tmp[-1].split("_")
        #del tmp1[2]
        #print())
        shutil.move(x, os.path.join( "MIL/data/unlocatable", tmp[-1] ) )
        #print( os.path.join( "/".join(tmp[:-1]), "_".join(tmp1) ) )
"""

# %%
imgs_db = {}
for img in imgs_train:
    tmp = img.split("/")[-1].split(".")[0].split("_")
    base_img = "_".join(tmp[:-2]) +".jpg"
    if base_img in imgs_db.keys():
        imgs_db[base_img].append( deepcopy(img.split("/")[-1]) )
    else:
        imgs_db[base_img] = [ deepcopy( img.split("/")[-1]) ]

# %%
import pickle
with open('ValImagesList.pkl', 'wb') as handle:
    pickle.dump(imgs_db, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# # Ordered Pair creation

# %% [markdown]
# ## Create Ordered Pair Image List

# %%
# Create dataframe
data =  pd.DataFrame(columns=["image","wound","location","day"])
for img in tqdm(imgs_train):
    #print(img)
    tmp = img.split("/")[-1]
    tmp2 = tmp.split("_")
    #print(len(tmp2))

    wound_id = "".join([tmp2[1], tmp2[3]])

    location = tmp2[-1].split(".")[0]
    #print(location)
    day = int(tmp2[5])
    data.loc[len(data.index)] = [img, wound_id, location, day]
# Out:
#   0%|          | 0/12564 [00:00<?, ?it/s]

# %%
# Create image pairs for training images
nump_sample = 8 # 8 for val, 10 for train
train_samples = []
train_label = []
count = 0

#L_train_samples = []
#R_train_samples = []

for wound in   data.wound.unique(): #  13 FOR TEST
    for location in data.location.unique():
        img_sample_df = data[ (data["wound"]==wound)
                                & (data["location"]==location) ].groupby('day',
                                                                        group_keys=False).apply(lambda x:
                                                                                                x.sample(nump_sample,replace=False)
                                                                                                if len(x) > nump_sample
                                                                                                else x.sample(nump_sample,replace=True))
        img_arr = np.array( img_sample_df["image"].index )
        img_arr = img_arr.reshape( len( img_sample_df['day'].unique() ), nump_sample)
        x = y = np.arange(0, len( img_sample_df['day'].unique() ), 1)
        combos = np.array(np.meshgrid(x, y)).T.reshape(-1, 2)
        drops = []
        for i in range(len(combos)):
            if combos[i][0] == combos[i][1]:
                drops.append(i)
        combos = np.delete(combos,drops,axis=0)
        #print(combos)
        for i in range(nump_sample):
            for j in range(i+1, nump_sample):
                for combo in combos:
                    #L_train_samples.append(img_arr[combo[0], i])
                    train_samples.append( ( data['image'].iloc[img_arr[combo[0], i]].split("/")[-1], data['image'].iloc[img_arr[combo[1], j]].split("/")[-1] )  )
                    train_label.append(1 if combo[0] > combo[1] else 0)
                    count += 1
#Save to numpy arrays
#x_train = deepcopy(np.concatenate((imgs_arr[L_train_samples],imgs_arr[R_train_samples]),axis=1))
#y_train = np.array(train_label, dtype=np.int32)

# %%
len(train_samples)
# Out:
# 23520

# %%
len(train_samples)

# %%
with open('ValOrderedPairsList.pkl', 'wb') as handle:
    pickle.dump(OrderedPairsList, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# !ls MIL/DTFD-MIL
# Out:
# data   LICENSE		 main_Extract_PerSlide.py  Patch_Generation  readme	save_model
# data_  Main_DTFD_MIL.py  Model			   Pre-processing    README.md	utils.py

# %%
# !pwd
# Out:
# /content/drive/MyDrive/BETR_Summer23
